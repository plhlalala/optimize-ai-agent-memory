# %% [markdown]
# # The Ultimate AI Agent Memory Lab: An End-to-End Implementation
#
# ### A Comprehensive, Hands-On Workshop for Building Smarter Agents
#
# Welcome to a detailed, practical exploration of memory in AI agents. This notebook is designed to be a definitive, end-to-end guide that moves beyond theory and into tangible, working code. We will implement **nine distinct memory strategies**, from the simplest to the most conceptually advanced, using a real large language model for generation, summarization, and embedding.
#
# **Objective:** By the end of this lab, you will have a deep, practical understanding of:
# - How each memory strategy works under the hood.
# - The specific strengths, weaknesses, and tradeoffs of each approach.
# - How to implement these strategies in Python using modern tools like `openai`, `faiss-cpu`, and `networkx`.
# - How the choice of memory architecture fundamentally changes an agent's conversational abilities, cost, and complexity.
#
# **Structure of the Lab:**
# 1.  **Part 1: The Core Framework.** We'll set up our environment, configure the LLM client, and build the foundational `AIAgent` and `BaseMemoryStrategy` classes.
# 2.  **Part 2: The Memory Implementations.** We will systematically implement and demonstrate all nine memory strategies. Each strategy will have its own dedicated section with:
#     *   **Detailed Theory:** Explaining the *what*, *why*, and *how*.
#     *   **Code Implementation:** A complete, commented Python class for the strategy.
#     *   **Live Demonstration:** A practical chat session designed to showcase the strategy's unique behavior.
#
# This notebook is intentionally lengthy and detailed to serve as a comprehensive reference. Let's begin by setting up our core components.

# %% [markdown]
# ## Part 1: Core Framework and Setup
#
# Before we can build memories, we need a brain (the LLM) and a body (the agent framework). This section handles all the preliminary setup.

# %% [markdown]
# ### Step 1.1: Installing Dependencies
#
# First, we need to install the necessary Python libraries. We'll need:
# - `openai`: The client library for interacting with the LLM API.
# - `numpy`: For numerical operations, especially with embeddings.
# - `faiss-cpu`: A library from Facebook AI for efficient similarity search, which will power our retrieval memory. It's a perfect in-memory vector database.
# - `networkx`: For creating and managing the knowledge graph in our Graph-Based Memory strategy.
# - `tiktoken`: To accurately count tokens and manage context window limits.

# %%
# !pip install openai numpy faiss-cpu networkx tiktoken
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)

# %% [markdown]
# ### Step 1.2: Configuring the LLM and Embedding Client
#
# Here, we'll set up the `OpenAI` client with the custom `base_url` and `api_key` you provided. This single client will be used for both text generation and creating embeddings.

# %%
# Import necessary libraries
import os
from openai import OpenAI

# --- IMPORTANT: API Key Configuration ---
# The API key is provided directly here for simplicity in this notebook.
# In a production environment, NEVER hardcode keys. Use environment variables
# or a secure secret management service.

# Define the API key for authentication.
API_KEY = ""
# Define the base URL for the API endpoint.
BASE_URL = "https://openrouter.ai/api/v1"

# Initialize the OpenAI client with the specified base URL and API key.
client = OpenAI(
    base_url=BASE_URL,
    api_key=API_KEY
)

# Print a confirmation message to indicate successful client setup.
print("OpenAI client configured successfully.")
# Out:
# OpenAI client configured successfully.

# %% [markdown]
# ### Step 1.3: Helper Functions for LLM Interaction and Token Counting
#
# To keep our main agent logic clean, we'll create wrapper functions for our API calls. We'll also set up a token counter, which is crucial for understanding the costs and limitations of our memory strategies.

# %%
# Import additional libraries for functionality.
import tiktoken
import time

# --- Model Configuration ---
# Define the specific models to be used for generation and embedding tasks.
# These are hardcoded for this lab but could be loaded from a config file.
GENERATION_MODEL = "openai/gpt-oss-safeguard-20b"
EMBEDDING_MODEL = "baai/bge-base-en-v1.5"

def generate_text(system_prompt: str, user_prompt: str) -> str:
    """
    Calls the LLM API to generate a text response.
    
    Args:
        system_prompt: The instruction that defines the AI's role and behavior.
        user_prompt: The user's input to which the AI should respond.
        
    Returns:
        The generated text content from the AI, or an error message.
    """
    try:
        # Create a chat completion request to the configured client.
        response = client.chat.completions.create(
            model=GENERATION_MODEL,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ]
        )
        # Extract and return the content of the AI's message.
        return response.choices[0].message.content
    except Exception as e:
        # Handle potential API errors gracefully.
        print(f"An error occurred during text generation: {e}")
        return "I'm sorry, I encountered an error and couldn't process your request."

def generate_embedding(text: str) -> list[float]:
    """
    Generates a numerical embedding for a given text string using the embedding model.
    
    Args:
        text: The input string to be converted into an embedding.
        
    Returns:
        A list of floats representing the embedding vector, or an empty list on error.
    """
    try:
        # Create an embedding request to the configured client.
        response = client.embeddings.create(
            model=EMBEDDING_MODEL,
            input=text
        )
        # Extract and return the embedding vector from the response data.
        return response.data[0].embedding
    except Exception as e:
        # Handle potential API errors gracefully.
        print(f"An error occurred during embedding generation: {e}")
        return []

# --- Token Counting Setup ---
# Initialize the tokenizer using tiktoken. 'cl100k_base' is a common encoding
# used by many modern models, including those from OpenAI and Llama.
# This allows us to accurately estimate the size of our prompts before sending them.
tokenizer = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """
    Counts the number of tokens in a given string using the pre-loaded tokenizer.
    
    Args:
        text: The string to be tokenized.
        
    Returns:
        The integer count of tokens.
    """
    # The `encode` method converts the string into a list of token IDs.
    # The length of this list is the token count.
    return len(tokenizer.encode(text))

# Print a confirmation message to indicate that these core functions are ready for use.
print("Helper functions and token counter are ready.")
# Out:
# Helper functions and token counter are ready.

# %% [markdown]
# ### Step 1.4: The Foundational Agent and Memory Classes
#
# Now we define the core structure of our system using the Strategy Design Pattern.
#
# - **`BaseMemoryStrategy`**: An abstract base class that defines the universal interface for any memory type. Every strategy we create will inherit from this, ensuring it can be seamlessly plugged into our agent.
# - **`AIAgent`**: The agent class itself. It is initialized with a memory strategy. Its `chat` method orchestrates the process of getting context from memory, querying the LLM, and updating the memory.

# %%
import abc

# --- Abstract Base Class for Memory Strategies ---
# This class defines the 'contract' that all memory strategies must follow.
# By using an Abstract Base Class (ABC), we ensure that any memory implementation
# we create will have the same core methods (add_message, get_context, clear),
# allowing them to be interchangeably plugged into the AIAgent.
class BaseMemoryStrategy(abc.ABC):
    """Abstract Base Class for all memory strategies."""
    
    @abc.abstractmethod
    def add_message(self, user_input: str, ai_response: str):
        """
        An abstract method that must be implemented by subclasses.
        It's responsible for adding a new user-AI interaction to the memory store.
        """
        pass

    @abc.abstractmethod
    def get_context(self, query: str) -> str:
        """
        An abstract method that must be implemented by subclasses.
        It retrieves and formats the relevant context from memory to be sent to the LLM.
        The 'query' parameter allows some strategies (like retrieval) to fetch context
        that is specifically relevant to the user's latest input.
        """
        pass

    @abc.abstractmethod
    def clear(self):
        """
        An abstract method that must be implemented by subclasses.
        It provides a way to reset the memory, which is useful for starting new conversations.
        """
        pass

# --- The Core AI Agent ---
# This class orchestrates the entire conversation flow. It is initialized with a
# specific memory strategy and uses it to manage the conversation's context.
class AIAgent:
    """The main AI Agent class, designed to work with any memory strategy."""
    
    def __init__(self, memory_strategy: BaseMemoryStrategy, system_prompt: str = "You are a helpful AI assistant."):
        """
        Initializes the agent.
        
        Args:
            memory_strategy: An instance of a class that inherits from BaseMemoryStrategy.
                             This determines how the agent will remember the conversation.
            system_prompt: The initial instruction given to the LLM to define its persona and task.
        """
        self.memory = memory_strategy
        self.system_prompt = system_prompt
        print(f"Agent initialized with {type(memory_strategy).__name__}.")

    def chat(self, user_input: str):
        """
        Handles a single turn of the conversation.
        
        Args:
            user_input: The latest message from the user.
        """
        print(f"\n{'='*25} NEW INTERACTION {'='*25}")
        print(f"User > {user_input}")
        
        # Step 1: Retrieve context from the agent's memory strategy.
        # This is where the specific memory logic (e.g., sequential, retrieval) is executed.
        start_time = time.time()
        context = self.memory.get_context(query=user_input)
        retrieval_time = time.time() - start_time
        
        # Step 2: Construct the full prompt for the LLM.
        # This combines the retrieved historical context with the user's current request.
        full_user_prompt = f"### MEMORY CONTEXT\n{context}\n\n### CURRENT REQUEST\n{user_input}"
        
        # Step 3: Provide detailed debug information.
        # This is crucial for understanding how the memory strategy affects the prompt size and cost.
        prompt_tokens = count_tokens(self.system_prompt + full_user_prompt)
        print("\n--- Agent Debug Info ---")
        print(f"Memory Retrieval Time: {retrieval_time:.4f} seconds")
        print(f"Estimated Prompt Tokens: {prompt_tokens}")
        print(f"\n[Full Prompt Sent to LLM]:\n---\nSYSTEM: {self.system_prompt}\nUSER: {full_user_prompt}\n---")
        
        # Step 4: Call the LLM to get a response.
        # The LLM uses the system prompt and the combined user prompt (context + new query) to generate a reply.
        start_time = time.time()
        ai_response = generate_text(self.system_prompt, full_user_prompt)
        generation_time = time.time() - start_time
        
        # Step 5: Update the memory with the latest interaction.
        # This ensures the current turn is available for future context retrieval.
        self.memory.add_message(user_input, ai_response)
        
        # Step 6: Display the AI's response and performance metrics.
        print(f"\nAgent > {ai_response}")
        print(f"(LLM Generation Time: {generation_time:.4f} seconds)")
        print(f"{'='*70}")

# %% [markdown]
# ## Part 2: Implementation and Demonstration of Memory Strategies
#
# This is the core of our lab. We will now implement each of the nine memory strategies one by one, followed immediately by a live demonstration to see how they perform in practice.

# %% [markdown]
# ### Strategy 1: Sequential (Keep-It-All) Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Short interactions, full fidelity                    | Hits token limit fast, expensive                       |
#
# **Theory:** This is the most straightforward memory type. It simply appends every user-AI interaction to a growing list. When generating a new response, the entire conversation history is formatted and sent to the LLM as context. This guarantees perfect, lossless recall within a single conversation session.
#
# However, its simplicity is its downfall in long conversations. The context grows linearly with each turn, leading to rapidly increasing API costs and eventually exceeding the LLM's maximum context window, which would cause an error or a truncated prompt.

# %%
# --- Strategy 1: Sequential (Keep-It-All) Memory ---
# This is the most basic memory strategy. It stores the entire conversation
# history in a simple list. While it provides perfect recall, it is not scalable
# as the context sent to the LLM grows with every turn, quickly becoming expensive
# and hitting token limits.
class SequentialMemory(BaseMemoryStrategy):
    def __init__(self):
        """Initializes the memory with an empty list to store conversation history."""
        self.history = []

    def add_message(self, user_input: str, ai_response: str):
        """
        Adds a new user-AI interaction to the history.
        Each interaction is stored as two dictionary entries in the list.
        """
        self.history.append({"role": "user", "content": user_input})
        self.history.append({"role": "assistant", "content": ai_response})

    def get_context(self, query: str) -> str:
        """
        Retrieves the entire conversation history and formats it into a single
        string to be used as context for the LLM. The 'query' parameter is ignored
        as this strategy always returns the full history.
        """
        # Join all messages into a single newline-separated string.
        return "\n".join([f"{turn['role'].capitalize()}: {turn['content']}" for turn in self.history])

    def clear(self):
        """Resets the conversation history by clearing the list."""
        self.history = []
        print("Sequential memory cleared.")

# %% [markdown]
# #### Demonstration of Sequential Memory
#
# **What to watch for:** Pay close attention to the `Estimated Prompt Tokens` in the debug output. You will see it increase significantly with each turn as the entire history is added to the prompt.

# %%
# Initialize and run the agent
# Create an instance of our SequentialMemory strategy.
sequential_memory = SequentialMemory()
# Create an AIAgent and inject the sequential memory strategy into it.
agent = AIAgent(memory_strategy=sequential_memory)

# --- Start the conversation ---
# First turn: The user introduces themselves.
agent.chat("Hi there! My name is Sam.")
# Second turn: The user states their interest.
agent.chat("I'm interested in learning about space exploration.")
# Third turn: The user tests the agent's memory.
agent.chat("What was the first thing I told you?")

# The agent has perfect recall because the entire history is in the context.
# Clean up the memory for the next demonstration.
sequential_memory.clear()
# Out:
# Agent initialized with SequentialMemory.
#
# ========================= NEW INTERACTION =========================
# User > Hi there! My name is Sam.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 23
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
#
#
# ### CURRENT REQUEST
# Hi there! My name is Sam.
# ---
#
# Agent > Hi Sam! 👋 How can I help you today?
# (LLM Generation Time: 0.4053 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > I'm interested in learning about space exploration.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 48
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# User: Hi there! My name is Sam.
# Assistant: Hi Sam! 👋 How can I help you today?
#
# ### CURRENT REQUEST
# I'm interested in learning about space exploration.
# ---
#
# Agent > Sure thing, Sam! 🚀 Space exploration is a vast and exciting field. Here’s a quick primer, and feel free to let me know which part sparks your curiosity—Mars missions, the Space Shuttle, the ISS, deep‑space probes, or something else entirely!
#
# ---
#
# ## 1️⃣ A Snapshot of the History
#
# | Era | Milestones | Key Players |
# |-----|-------------|-------------|
# | **Early 20th c.** | First rockets (Katyusha, V-2) | Russia, Germany |
# | **1940‑50s** | Sputnik 1 (1962) – first satellite | USSR |
# | **1960‑70s** | Apollo moon landings (1969‑75) | USA (NASA) |
# | **1970‑80s** | Mars Rovers (Mars 3, Viking) | USSR, NASA |
# | **1980‑90s** | Hubble Space Telescope (1990), Voyager missions | NASA, ESA |
# | **2000‑present** | Mars rovers (Sojourner, Spirit, Opportunity, Curiosity, Perseverance), ISS, private ventures (SpaceX, Blue Origin) | Multiple national & private agencies |
#
# ---
#
# ## 2️⃣ Major Space Agencies (just the big players)
#
# | Agency | Country | Famous Missions |
# |--------|---------|-----------------|
# | NASA | USA | Apollo, Voyager, Hubble, Mars Curiosity, SpaceX collaborations |
# | ESA | European Union | Rosetta, ExoMars, Galileo |
# | CNSA | China | Chang'e lunar probes, Tianwen‑1 Mars mission |
# | Roscosmos | Russia | Soyuz, Luna, Mars 2020 |
# | ISRO | India | Chandrayaan, Mars Orbiter Mission |
# | JAXA | Japan | Hayabusa, Akatsuki |
# | Private (SpaceX, Blue Origin, Virgin Galactic) | USA | Starship, New Glenn, Blue Moon |
#
# ---
#
# ## 3️⃣ Types of Missions
#
# - **Orbital** (satellites, ISS) – study Earth, other planets, deep space.
# - **Flyby** – visit planets and do not orbit (e.g., Voyager 1 & 2, New Horizons).
# - **Lander/Probe** – touch surface (e.g., Mars rovers, Luna 2).
# - **Manned** – astronauts (Apollo, ISS, future Artemis crewed moon).
# - **Commercial** – satellite deployment, tourism, mining concepts.
#
# ---
#
# ## 4️⃣ Iconic Missions Worth Knowing
#
# | Mission | Year | Goal | Outcome |
# |---------|------|------|---------|
# | **Sputnik 1** | 1957 | First artificial satellite | Kick‑off of the space age |
# | **Apollo 11** | 1969 | First moon landing | Humans on the Moon |
# | **Viking 1** | 1975 | Mars surface probe | First successful Mars surface mission |
# | **Hubble** | 1990 | Deep‑space telescope | Unprecedented images, cosmology breakthroughs |
# | **Curiosity** | 2012 | Mars geology & habitability | Ongoing mission, methane findings |
# | **Voyager 1 & 2** | 1977 | Outer planets | First humans outside heliosphere (Voyager 1) |
# | **New Horizons** | 2015 | Pluto flyby | First close images of Pluto |
# | **Artemis III** | 2024 (planned) | Return humans to Moon | First crewed lunar landing since Apollo |
#
# ---
#
# ## 5️⃣ Current Hot Topics
#
# 1. **Mars Sample Return** – NASA+ESA plan to bring Martian soil back to Earth.
# 2. **Artemis Program** – Moon base and deeper space infrastructure.
# 3. **SpaceX Starship** – Reusable spacecraft for Mars colonization.
# 4. **Exoplanet Exploration** – JWST, upcoming missions like PLATO, LUVOIR.
# 5. **Space Resource Utilization** – mining asteroids, lunar regolith for life support.
#
# ---
#
# ## 6️⃣ How to Dive Deeper
#
# - **Books**: *“The Right Stuff”* (Tom Wolfe), *“Rocket Boys”* (Elbert Hubbard), *“Space: The Complete Guide”* (Clyde R. B.).
# - **Documentaries**: *“Cosmos”* (Carl Sagan), *“The Farthest”* (Voyager), *“For All Mankind”* (Apollo footage).
# - **Websites**: NASA, ESA, JAXA, SpaceX’s mission pages.
# - **YouTube Channels**: *PBS Space Time*, *Futurism*, *NASA’s official channel*.
#
# ---
#
# ### What would you like to explore next?
#
# - **Deep‑space probes** (Voyager, New Horizons)
# - **Human spaceflight** (Apollo, ISS, Artemis)
# - **Mars missions** (rovers, sample return)
# - **The future of space travel** (Starship, Lunar Gateway)
# - **Space policy & economics** (privatization, budgets)
#
# Let me know which thread pulls you in, or if you’d like a deeper dive into any of the above topics!
# (LLM Generation Time: 1.3666 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > What was the first thing I told you?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 1180
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# User: Hi there! My name is Sam.
# Assistant: Hi Sam! 👋 How can I help you today?
# User: I'm interested in learning about space exploration.
# Assistant: Sure thing, Sam! 🚀 Space exploration is a vast and exciting field. Here’s a quick primer, and feel free to let me know which part sparks your curiosity—Mars missions, the Space Shuttle, the ISS, deep‑space probes, or something else entirely!
#
# ---
#
# ## 1️⃣ A Snapshot of the History
#
# | Era | Milestones | Key Players |
# |-----|-------------|-------------|
# | **Early 20th c.** | First rockets (Katyusha, V-2) | Russia, Germany |
# | **1940‑50s** | Sputnik 1 (1962) – first satellite | USSR |
# | **1960‑70s** | Apollo moon landings (1969‑75) | USA (NASA) |
# | **1970‑80s** | Mars Rovers (Mars 3, Viking) | USSR, NASA |
# | **1980‑90s** | Hubble Space Telescope (1990), Voyager missions | NASA, ESA |
# | **2000‑present** | Mars rovers (Sojourner, Spirit, Opportunity, Curiosity, Perseverance), ISS, private ventures (SpaceX, Blue Origin) | Multiple national & private agencies |
#
# ---
#
# ## 2️⃣ Major Space Agencies (just the big players)
#
# | Agency | Country | Famous Missions |
# |--------|---------|-----------------|
# | NASA | USA | Apollo, Voyager, Hubble, Mars Curiosity, SpaceX collaborations |
# | ESA | European Union | Rosetta, ExoMars, Galileo |
# | CNSA | China | Chang'e lunar probes, Tianwen‑1 Mars mission |
# | Roscosmos | Russia | Soyuz, Luna, Mars 2020 |
# | ISRO | India | Chandrayaan, Mars Orbiter Mission |
# | JAXA | Japan | Hayabusa, Akatsuki |
# | Private (SpaceX, Blue Origin, Virgin Galactic) | USA | Starship, New Glenn, Blue Moon |
#
# ---
#
# ## 3️⃣ Types of Missions
#
# - **Orbital** (satellites, ISS) – study Earth, other planets, deep space.
# - **Flyby** – visit planets and do not orbit (e.g., Voyager 1 & 2, New Horizons).
# - **Lander/Probe** – touch surface (e.g., Mars rovers, Luna 2).
# - **Manned** – astronauts (Apollo, ISS, future Artemis crewed moon).
# - **Commercial** – satellite deployment, tourism, mining concepts.
#
# ---
#
# ## 4️⃣ Iconic Missions Worth Knowing
#
# | Mission | Year | Goal | Outcome |
# |---------|------|------|---------|
# | **Sputnik 1** | 1957 | First artificial satellite | Kick‑off of the space age |
# | **Apollo 11** | 1969 | First moon landing | Humans on the Moon |
# | **Viking 1** | 1975 | Mars surface probe | First successful Mars surface mission |
# | **Hubble** | 1990 | Deep‑space telescope | Unprecedented images, cosmology breakthroughs |
# | **Curiosity** | 2012 | Mars geology & habitability | Ongoing mission, methane findings |
# | **Voyager 1 & 2** | 1977 | Outer planets | First humans outside heliosphere (Voyager 1) |
# | **New Horizons** | 2015 | Pluto flyby | First close images of Pluto |
# | **Artemis III** | 2024 (planned) | Return humans to Moon | First crewed lunar landing since Apollo |
#
# ---
#
# ## 5️⃣ Current Hot Topics
#
# 1. **Mars Sample Return** – NASA+ESA plan to bring Martian soil back to Earth.
# 2. **Artemis Program** – Moon base and deeper space infrastructure.
# 3. **SpaceX Starship** – Reusable spacecraft for Mars colonization.
# 4. **Exoplanet Exploration** – JWST, upcoming missions like PLATO, LUVOIR.
# 5. **Space Resource Utilization** – mining asteroids, lunar regolith for life support.
#
# ---
#
# ## 6️⃣ How to Dive Deeper
#
# - **Books**: *“The Right Stuff”* (Tom Wolfe), *“Rocket Boys”* (Elbert Hubbard), *“Space: The Complete Guide”* (Clyde R. B.).
# - **Documentaries**: *“Cosmos”* (Carl Sagan), *“The Farthest”* (Voyager), *“For All Mankind”* (Apollo footage).
# - **Websites**: NASA, ESA, JAXA, SpaceX’s mission pages.
# - **YouTube Channels**: *PBS Space Time*, *Futurism*, *NASA’s official channel*.
#
# ---
#
# ### What would you like to explore next?
#
# - **Deep‑space probes** (Voyager, New Horizons)
# - **Human spaceflight** (Apollo, ISS, Artemis)
# - **Mars missions** (rovers, sample return)
# - **The future of space travel** (Starship, Lunar Gateway)
# - **Space policy & economics** (privatization, budgets)
#
# Let me know which thread pulls you in, or if you’d like a deeper dive into any of the above topics!
#
# ### CURRENT REQUEST
# What was the first thing I told you?
# ---
#
# Agent > The first thing you told me was:
#
# > “Hi there! My name is Sam.”
# (LLM Generation Time: 0.3280 seconds)
# ======================================================================
# Sequential memory cleared.

# %% [markdown]
# ### Strategy 2: Sliding Window Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Mid-length chats, recent relevance matters           | Forgets early context                                  |
#
# **Theory:** This strategy addresses the primary issue of Sequential Memory by only keeping the most recent `N` conversation turns. It uses a `deque` (double-ended queue) with a fixed maximum length. When a new interaction is added and the deque is full, the oldest interaction is automatically discarded.
#
# This keeps the context size constant, making costs predictable and preventing context window overflow. The major tradeoff is amnesia: any information mentioned before the window's cutoff point is permanently forgotten.

# %%
# Import the deque class from the collections module. A deque is a double-ended
# queue that is highly efficient for adding and removing elements from either end.
from collections import deque

# --- Strategy 2: Sliding Window Memory ---
# This strategy keeps only the 'N' most recent turns of the conversation.
# It prevents the context from growing indefinitely, making it scalable and
# cost-effective, but at the cost of forgetting older information.
class SlidingWindowMemory(BaseMemoryStrategy):
    def __init__(self, window_size: int = 4): # window_size is number of turns (user + AI = 1 turn)
        """
        Initializes the memory with a deque of a fixed size.
        
        Args:
            window_size: The number of conversational turns to keep in memory.
                         A single turn consists of one user message and one AI response.
        """
        # A deque with 'maxlen' will automatically discard the oldest item
        # when a new item is added and the deque is full. This is the core
        # mechanism of the sliding window. We store turns, so maxlen is window_size.
        self.history = deque(maxlen=window_size)

    def add_message(self, user_input: str, ai_response: str):
        """
        Adds a new conversational turn to the history. If the deque is full,
        the oldest turn is automatically removed.
        """
        # Each turn (user input + AI response) is stored as a single element
        # in the deque. This makes it easy to manage the window size by turns.
        self.history.append([
            {"role": "user", "content": user_input},
            {"role": "assistant", "content": ai_response}
        ])

    def get_context(self, query: str) -> str:
        """
        Retrieves the conversation history currently within the window and
        formats it into a single string. The 'query' parameter is ignored.
        """
        # Create a temporary list to hold the formatted messages.
        context_list = []
        # Iterate through each turn stored in the deque.
        for turn in self.history:
            # Iterate through the user and assistant messages within that turn.
            for message in turn:
                # Format the message and add it to our list.
                context_list.append(f"{message['role'].capitalize()}: {message['content']}")
        # Join all the formatted messages into a single string, separated by newlines.
        return "\n".join(context_list)

    def clear(self):
        """Resets the conversation history by clearing the deque."""
        self.history.clear()
        print("Sliding window memory cleared.")

# %% [markdown]
# #### Demonstration of Sliding Window Memory
#
# **What to watch for:** We'll set a window size of 2 turns. After the third turn, the very first piece of information (the user's name) will be pushed out of the context window. The agent will then fail to recall it.

# %%
# Initialize with a small window size of 2 turns.
# This means the agent will only remember the last two user-AI interactions.
sliding_memory = SlidingWindowMemory(window_size=2)
# Create an AIAgent and inject the sliding window memory strategy.
agent = AIAgent(memory_strategy=sliding_memory)

# --- Start the conversation ---
# First turn: The user introduces themselves. This is Turn 1.
agent.chat("My name is Priya and I'm a software developer.")
# Second turn: The user provides more details. The memory now holds Turn 1 and Turn 2.
agent.chat("I work primarily with Python and cloud technologies.")
# Third turn: The user mentions a hobby. Adding this turn pushes Turn 1 out of the
# fixed-size deque. The memory now only holds Turn 2 and Turn 3.
agent.chat("My favorite hobby is hiking.")

# Now, ask about the first thing mentioned.
# The context sent to the LLM will only contain the information about Python/cloud and hiking.
# The information about the user's name has been forgotten.
agent.chat("What is my name?")
# The agent will likely fail, as the first turn has been pushed out of the window.

# Clean up the memory for the next demonstration.
sliding_memory.clear()
# Out:
# Agent initialized with SlidingWindowMemory.
#
# ========================= NEW INTERACTION =========================
# User > My name is Priya and I'm a software developer.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 27
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
#
#
# ### CURRENT REQUEST
# My name is Priya and I'm a software developer.
# ---
#
# Agent > Hi Priya! Great to meet a fellow software developer. How can I assist you today? Whether it's coding help, project ideas, or just a quick chat about the latest tech trends—just let me know!
# (LLM Generation Time: 0.5826 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > I work primarily with Python and cloud technologies.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 84
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# User: My name is Priya and I'm a software developer.
# Assistant: Hi Priya! Great to meet a fellow software developer. How can I assist you today? Whether it's coding help, project ideas, or just a quick chat about the latest tech trends—just let me know!
#
# ### CURRENT REQUEST
# I work primarily with Python and cloud technologies.
# ---
#
# Agent > That’s a great stack to work with! Whether you’re building cloud‑native applications, automating deployments, or diving into AI/ML pipelines, Python has a rich ecosystem. How can I help you today?
# - Looking for best‑practice patterns for cloud‑native Python apps?
# - Need guidance on serverless frameworks, containers, or IaC tools?
# - Curious about scaling, monitoring, or security in the cloud?
# - Or maybe you’d like to brainstorm a project or review some code?
#
# Just let me know what you’d like to explore!
# (LLM Generation Time: 0.5514 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > My favorite hobby is hiking.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 212
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# User: My name is Priya and I'm a software developer.
# Assistant: Hi Priya! Great to meet a fellow software developer. How can I assist you today? Whether it's coding help, project ideas, or just a quick chat about the latest tech trends—just let me know!
# User: I work primarily with Python and cloud technologies.
# Assistant: That’s a great stack to work with! Whether you’re building cloud‑native applications, automating deployments, or diving into AI/ML pipelines, Python has a rich ecosystem. How can I help you today?
# - Looking for best‑practice patterns for cloud‑native Python apps?
# - Need guidance on serverless frameworks, containers, or IaC tools?
# - Curious about scaling, monitoring, or security in the cloud?
# - Or maybe you’d like to brainstorm a project or review some code?
#
# Just let me know what you’d like to explore!
#
# ### CURRENT REQUEST
# My favorite hobby is hiking.
# ---
#
# Agent > That’s a fantastic hobby—there’s nothing quite like the fresh air and the sense of accomplishment after a good hike!
# A few quick questions so I can tailor my suggestions:
#
# 1. **Where do you usually hike?** (e.g., local state parks, national trails, high‑altitude mountains, or beach cliffs?)
# 2. **What’s your preferred level of difficulty?** (short nature walks, moderate day hikes, or multi‑day backpacking?)
# 3. **Do you have a favorite season or weather you’re comfortable with?**
# 4. **Any particular gear or app you’re already using?** (e.g., GPS watches, trail‑mapping apps, or a favorite backpack brand?)
#
# In the meantime, here are some general pointers and resources that might be handy:
#
# | Topic | Quick Tips | Resources |
# |-------|------------|-----------|
# | **Safety** | Pack a basic first‑aid kit, a map or offline trail app, and tell someone your plan. Check weather alerts and trail closures. | [AllTrails](https://www.alltrails.com), [TrailSense](https://www.trail-sense.com) |
# | **Hydration & Nutrition** | Use a hydration bladder or water bottles and carry lightweight, calorie‑dense snacks. Aim for 2–3 L of water per 3 h of moderate hiking. | “Hydration and Nutrition for Hikers” – National Park Service |
# | **Gear** | Consider a lightweight, breathable jacket, layered clothing, and sturdy hiking boots with good ankle support. For longer trips, a lightweight stove and a compact sleeping system. | [REI’s Gear Guides](https://www.rei.com/gear) |
# | **Trail Planning** | Plan a route that matches your fitness level, check elevation gain, and estimate total time. Leave a buffer for rest or unexpected detours. | [Google Maps – Terrain view](https://maps.google.com), [Gaia GPS](https://www.gaia.com) |
# | **Eco‑Friendly Practices** | Stick to established trails, carry out what you bring in, and minimize impact on wildlife. | Leave No Trace principles (https://lnt.org) |
#
# Let me know which of these areas you'd like to dive deeper into—or if you’re looking for specific trail recommendations in a region you love. Happy hiking, Priya! 🚶‍♀️🌲
# (LLM Generation Time: 0.9637 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > What is my name?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 661
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# User: I work primarily with Python and cloud technologies.
# Assistant: That’s a great stack to work with! Whether you’re building cloud‑native applications, automating deployments, or diving into AI/ML pipelines, Python has a rich ecosystem. How can I help you today?
# - Looking for best‑practice patterns for cloud‑native Python apps?
# - Need guidance on serverless frameworks, containers, or IaC tools?
# - Curious about scaling, monitoring, or security in the cloud?
# - Or maybe you’d like to brainstorm a project or review some code?
#
# Just let me know what you’d like to explore!
# User: My favorite hobby is hiking.
# Assistant: That’s a fantastic hobby—there’s nothing quite like the fresh air and the sense of accomplishment after a good hike!
# A few quick questions so I can tailor my suggestions:
#
# 1. **Where do you usually hike?** (e.g., local state parks, national trails, high‑altitude mountains, or beach cliffs?)
# 2. **What’s your preferred level of difficulty?** (short nature walks, moderate day hikes, or multi‑day backpacking?)
# 3. **Do you have a favorite season or weather you’re comfortable with?**
# 4. **Any particular gear or app you’re already using?** (e.g., GPS watches, trail‑mapping apps, or a favorite backpack brand?)
#
# In the meantime, here are some general pointers and resources that might be handy:
#
# | Topic | Quick Tips | Resources |
# |-------|------------|-----------|
# | **Safety** | Pack a basic first‑aid kit, a map or offline trail app, and tell someone your plan. Check weather alerts and trail closures. | [AllTrails](https://www.alltrails.com), [TrailSense](https://www.trail-sense.com) |
# | **Hydration & Nutrition** | Use a hydration bladder or water bottles and carry lightweight, calorie‑dense snacks. Aim for 2–3 L of water per 3 h of moderate hiking. | “Hydration and Nutrition for Hikers” – National Park Service |
# | **Gear** | Consider a lightweight, breathable jacket, layered clothing, and sturdy hiking boots with good ankle support. For longer trips, a lightweight stove and a compact sleeping system. | [REI’s Gear Guides](https://www.rei.com/gear) |
# | **Trail Planning** | Plan a route that matches your fitness level, check elevation gain, and estimate total time. Leave a buffer for rest or unexpected detours. | [Google Maps – Terrain view](https://maps.google.com), [Gaia GPS](https://www.gaia.com) |
# | **Eco‑Friendly Practices** | Stick to established trails, carry out what you bring in, and minimize impact on wildlife. | Leave No Trace principles (https://lnt.org) |
#
# Let me know which of these areas you'd like to dive deeper into—or if you’re looking for specific trail recommendations in a region you love. Happy hiking, Priya! 🚶‍♀️🌲
#
# ### CURRENT REQUEST
# What is my name?
# ---
#
# Agent > I don’t actually have a confirmed name from you. In the earlier conversation I used “Priya” as a placeholder when I was talking about hiking tips, but that was just a guess. If you let me know your real name or just how you’d like to be addressed, I’ll remember it for future messages!
# (LLM Generation Time: 0.7858 seconds)
# ======================================================================
# Sliding window memory cleared.

# %% [markdown]
# ### Strategy 3: Summarization Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Long conversations, general context needed           | May lose fine details                                  |
#
# **Theory:** This strategy attempts to get the best of both worlds. Instead of just dropping old messages, it uses the LLM itself to periodically create a running summary of the conversation. It maintains a temporary buffer of recent messages. Once the buffer reaches a certain size, its content is summarized and merged with the previous summary.
#
# The context sent to the LLM is a combination of the `running_summary` and the `current_buffer`. This keeps the context size manageable while retaining the gist of the entire conversation. The main risk is information loss: if the LLM's summary misses a crucial but subtle detail, that detail is lost forever.

# %%
# --- Strategy 3: Summarization Memory ---
# This strategy aims to manage long conversations by periodically summarizing them.
# It keeps a buffer of recent messages. When the buffer reaches a certain size,
# it uses an LLM call to consolidate the buffer's content with a running summary.
# This keeps the context size manageable while retaining the gist of the conversation.
# The main risk is information loss if the summary is not perfect.
class SummarizationMemory(BaseMemoryStrategy):
    def __init__(self, summary_threshold: int = 4): # Default: Summarize after 4 messages (2 turns)
        """
        Initializes the summarization memory.
        
        Args:
            summary_threshold: The number of messages (user + AI) to accumulate in the
                             buffer before triggering a summarization.
        """
        # Stores the continuously updated summary of the conversation so far.
        self.running_summary = ""
        # A temporary list to hold recent messages before they are summarized.
        self.buffer = []
        # The threshold that triggers the summarization process.
        self.summary_threshold = summary_threshold

    def add_message(self, user_input: str, ai_response: str):
        """
        Adds a new user-AI interaction to the buffer. If the buffer size
        reaches the threshold, it triggers the memory consolidation process.
        """
        # Append the latest user and AI messages to the temporary buffer.
        self.buffer.append({"role": "user", "content": user_input})
        self.buffer.append({"role": "assistant", "content": ai_response})

        # Check if the buffer has reached its capacity.
        if len(self.buffer) >= self.summary_threshold:
            # If so, call the method to summarize the buffer's contents.
            self._consolidate_memory()

    def _consolidate_memory(self):
        """
        Uses the LLM to summarize the contents of the buffer and merge it
        with the existing running summary.
        """
        print("\n--- [Memory Consolidation Triggered] ---")
        # Convert the list of buffered messages into a single formatted string.
        buffer_text = "\n".join([f"{msg['role'].capitalize()}: {msg['content']}" for msg in self.buffer])
        
        # Construct a specific prompt for the LLM to perform the summarization task.
        # It provides the existing summary and the new conversation text, asking for
        # a single, updated summary.
        summarization_prompt = (
            f"You are a summarization expert. Your task is to create a concise summary of a conversation. "
            f"Combine the 'Previous Summary' with the 'New Conversation' into a single, updated summary. "
            f"Capture all key facts, names, and decisions.\n\n"
            f"### Previous Summary:\n{self.running_summary}\n\n"
            f"### New Conversation:\n{buffer_text}\n\n"
            f"### Updated Summary:"
        )
        
        # Call the LLM with a specific system prompt to get the new summary.
        new_summary = generate_text("You are an expert summarization engine.", summarization_prompt)
        # Replace the old summary with the newly generated, consolidated one.
        self.running_summary = new_summary
        # Clear the buffer, as its contents have now been incorporated into the summary.
        self.buffer = [] 
        print(f"--- [New Summary: '{self.running_summary}'] ---")

    def get_context(self, query: str) -> str:
        """
        Constructs the context to be sent to the LLM. It combines the long-term
        running summary with the short-term buffer of recent messages.
        The 'query' parameter is ignored as this strategy provides a general context.
        """
        # Format the messages currently in the buffer.
        buffer_text = "\n".join([f"{msg['role'].capitalize()}: {msg['content']}" for msg in self.buffer])
        # Return a combined context of the historical summary and the most recent, not-yet-summarized messages.
        return f"### Summary of Past Conversation:\n{self.running_summary}\n\n### Recent Messages:\n{buffer_text}"

    def clear(self):
        """Resets the memory by clearing the summary and the buffer."""
        self.running_summary = ""
        self.buffer = []
        print("Summarization memory cleared.")

# %% [markdown]
# #### Demonstration of Summarization Memory
#
# **What to watch for:** A `[Memory Consolidation Triggered]` message will appear after the second turn (since our threshold is 4 messages). The context for the subsequent turn will include the new, AI-generated summary. We'll see if the agent can recall details from the first turn, which now only exist in the summary.

# %%
# Initialize the SummarizationMemory with a threshold of 4 messages (2 turns).
# This means a summary will be generated after the second full interaction.
summarization_memory = SummarizationMemory(summary_threshold=4)
# Create an AIAgent and inject the summarization memory strategy.
agent = AIAgent(memory_strategy=summarization_memory)

# --- Start the conversation ---
# First turn: The user provides initial details.
agent.chat("I'm starting a new company called 'Innovatech'. Our focus is on sustainable energy.")
# Second turn: The user gives more specific information. After the AI responds to this,
# the buffer will contain 4 messages, triggering the memory consolidation process.
agent.chat("Our first product will be a smart solar panel, codenamed 'Project Helios'.")

# Third turn: The user adds another detail. The previous information now exists only in the running summary.
agent.chat("The marketing budget is set at $50,000.")
# Fourth turn: The user tests the agent's memory. The context sent to the LLM will consist of
# the AI-generated summary plus the most recent (post-summary) message about the budget.
agent.chat("What is the name of my company and its first product?")
# The agent's ability to answer correctly depends entirely on the quality of the LLM's summary.

# Clean up the memory for the next demonstration.
summarization_memory.clear()
# Out:
# Agent initialized with SummarizationMemory.
#
# ========================= NEW INTERACTION =========================
# User > I'm starting a new company called 'Innovatech'. Our focus is on sustainable energy.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 45
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Summary of Past Conversation:
#
#
# ### Recent Messages:
#
#
# ### CURRENT REQUEST
# I'm starting a new company called 'Innovatech'. Our focus is on sustainable energy.
# ---
#
# Agent > Congratulations on launching **Innovatech**! 🎉
# Starting a sustainable‑energy venture is both exciting and impactful. Below are a few quick ideas and resources to help you get the momentum rolling—feel free to let me know which areas you’d like to dive deeper into.
#
# ---
#
# ## 1. Clarify Your Niche
#
# | Option | What It Covers | Why It Matters |
# |--------|----------------|----------------|
# | **Solar tech** | Panels, trackers, micro‑inverters | Highest market share today |
# | **Energy storage** | Batteries, thermal storage | Addresses intermittency of renewables |
# | **Grid‑integration** | Smart inverters, demand‑response | Enables larger adoption |
# | **Bio‑energy** | Biogas, algae biofuels | Low‑carbon alternative for heavy industry |
# | **Circular economy** | Recycling e‑components, repurposing batteries | Adds ESG credibility |
#
# > **Tip:** Pick one or two to start; depth beats breadth early on.
#
# ---
#
# ## 2. Build a Strong Brand Narrative
#
# 1. **Mission Statement**
#    *“Empowering communities with affordable, clean energy solutions for a resilient future.”*
#
# 2. **Value Proposition**
#    - **Sustainability** (100% renewable supply chain)
#    - **Affordability** (cost‑effective tech for both urban & rural markets)
#    - **Innovation** (AI‑driven performance analytics)
#
# 3. **Visual Identity**
#    - Green/blue palette → conveys eco‑trust
#    - Clean, minimalist logo → modern tech feel
#
# 4. **Storytelling Angles**
#    - *“From our prototype in the lab to rooftop panels in rural villages.”*
#    - Highlight early adopters or pilot projects.
#
# ---
#
# ## 3. Outline a Minimum Viable Product (MVP)
#
# | Component | Suggested Features | Timeframe |
# |-----------|--------------------|-----------|
# | **Hardware** | Solar panels or battery cells | 6–12 months |
# | **Software** | Cloud dashboard, predictive maintenance | 4–8 months |
# | **Service** | Installation & maintenance network | 3–6 months |
# | **Financing** | Pay‑as‑you‑go model or green bonds | 3–12 months |
#
# > **Pro Tip:** Leverage partnerships with existing hardware suppliers to speed up MVP delivery.
#
# ---
#
# ## 4. Funding & Partnerships
#
# | Stage | Typical Sources | What You Need |
# |-------|-----------------|---------------|
# | **Seed** | Angel investors, grants (e.g., US Dept. Energy) | Business plan, prototype |
# | **Series A** | VC focused on cleantech (e.g., Breakthrough Energy Ventures) | Market validation, revenue projections |
# | **Strategic Partners** | Utilities, OEMs, NGOs | Joint R&D, market access |
#
# > *Consider a “green” incubator or accelerator to accelerate network building.*
#
# ---
#
# ## 5. Regulatory Landscape
#
# - **Local Permits** – Check zoning, grid connection standards.
# - **Renewable Incentives** – Tax credits, feed‑in tariffs, net metering.
# - **Carbon Credits** – Potential revenue stream if you can certify emissions savings.
#
# > *Keep an eye on policy changes; they often trigger new opportunities.*
#
# ---
#
# ## 6. Go‑to‑Market Strategy
#
# 1. **Pilot Projects** – Start with a community or corporate pilot.
# 2. **Case Studies** – Document ROI, energy savings, maintenance stats.
# 3. **Thought Leadership** – Publish white papers or host webinars.
# 4. **Sales Channels** – Direct B2B sales + online marketplace for smaller installations.
#
# ---
#
# ## 7. Quick Checklist to Kick Off
#
# - [ ] Finalize product concept & technical specs
# - [ ] Secure IP (patents, trademarks)
# - [ ] Build a lean prototype & test it in a real environment
# - [ ] Draft a one‑pager investor deck
# - [ ] Register company & choose a legal structure (LLC, C‑Corp, etc.)
# - [ ] Set up a basic website + social media profiles
# - [ ] Reach out to local government or NGO partners
#
# ---
#
# ## Next Steps
#
# * Are you looking for help drafting a pitch deck?
# * Need a deeper dive into a particular tech (e.g., battery chemistries)?
# * Want to explore potential investors in the sustainable‑energy space?
#
# Just let me know where you’d like to focus, and we can drill down further! 🚀
# (LLM Generation Time: 2.0505 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Our first product will be a smart solar panel, codenamed 'Project Helios'.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 1011
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Summary of Past Conversation:
#
#
# ### Recent Messages:
# User: I'm starting a new company called 'Innovatech'. Our focus is on sustainable energy.
# Assistant: Congratulations on launching **Innovatech**! 🎉
# Starting a sustainable‑energy venture is both exciting and impactful. Below are a few quick ideas and resources to help you get the momentum rolling—feel free to let me know which areas you’d like to dive deeper into.
#
# ---
#
# ## 1. Clarify Your Niche
#
# | Option | What It Covers | Why It Matters |
# |--------|----------------|----------------|
# | **Solar tech** | Panels, trackers, micro‑inverters | Highest market share today |
# | **Energy storage** | Batteries, thermal storage | Addresses intermittency of renewables |
# | **Grid‑integration** | Smart inverters, demand‑response | Enables larger adoption |
# | **Bio‑energy** | Biogas, algae biofuels | Low‑carbon alternative for heavy industry |
# | **Circular economy** | Recycling e‑components, repurposing batteries | Adds ESG credibility |
#
# > **Tip:** Pick one or two to start; depth beats breadth early on.
#
# ---
#
# ## 2. Build a Strong Brand Narrative
#
# 1. **Mission Statement**
#    *“Empowering communities with affordable, clean energy solutions for a resilient future.”*
#
# 2. **Value Proposition**
#    - **Sustainability** (100% renewable supply chain)
#    - **Affordability** (cost‑effective tech for both urban & rural markets)
#    - **Innovation** (AI‑driven performance analytics)
#
# 3. **Visual Identity**
#    - Green/blue palette → conveys eco‑trust
#    - Clean, minimalist logo → modern tech feel
#
# 4. **Storytelling Angles**
#    - *“From our prototype in the lab to rooftop panels in rural villages.”*
#    - Highlight early adopters or pilot projects.
#
# ---
#
# ## 3. Outline a Minimum Viable Product (MVP)
#
# | Component | Suggested Features | Timeframe |
# |-----------|--------------------|-----------|
# | **Hardware** | Solar panels or battery cells | 6–12 months |
# | **Software** | Cloud dashboard, predictive maintenance | 4–8 months |
# | **Service** | Installation & maintenance network | 3–6 months |
# | **Financing** | Pay‑as‑you‑go model or green bonds | 3–12 months |
#
# > **Pro Tip:** Leverage partnerships with existing hardware suppliers to speed up MVP delivery.
#
# ---
#
# ## 4. Funding & Partnerships
#
# | Stage | Typical Sources | What You Need |
# |-------|-----------------|---------------|
# | **Seed** | Angel investors, grants (e.g., US Dept. Energy) | Business plan, prototype |
# | **Series A** | VC focused on cleantech (e.g., Breakthrough Energy Ventures) | Market validation, revenue projections |
# | **Strategic Partners** | Utilities, OEMs, NGOs | Joint R&D, market access |
#
# > *Consider a “green” incubator or accelerator to accelerate network building.*
#
# ---
#
# ## 5. Regulatory Landscape
#
# - **Local Permits** – Check zoning, grid connection standards.
# - **Renewable Incentives** – Tax credits, feed‑in tariffs, net metering.
# - **Carbon Credits** – Potential revenue stream if you can certify emissions savings.
#
# > *Keep an eye on policy changes; they often trigger new opportunities.*
#
# ---
#
# ## 6. Go‑to‑Market Strategy
#
# 1. **Pilot Projects** – Start with a community or corporate pilot.
# 2. **Case Studies** – Document ROI, energy savings, maintenance stats.
# 3. **Thought Leadership** – Publish white papers or host webinars.
# 4. **Sales Channels** – Direct B2B sales + online marketplace for smaller installations.
#
# ---
#
# ## 7. Quick Checklist to Kick Off
#
# - [ ] Finalize product concept & technical specs
# - [ ] Secure IP (patents, trademarks)
# - [ ] Build a lean prototype & test it in a real environment
# - [ ] Draft a one‑pager investor deck
# - [ ] Register company & choose a legal structure (LLC, C‑Corp, etc.)
# - [ ] Set up a basic website + social media profiles
# - [ ] Reach out to local government or NGO partners
#
# ---
#
# ## Next Steps
#
# * Are you looking for help drafting a pitch deck?
# * Need a deeper dive into a particular tech (e.g., battery chemistries)?
# * Want to explore potential investors in the sustainable‑energy space?
#
# Just let me know where you’d like to focus, and we can drill down further! 🚀
#
# ### CURRENT REQUEST
# Our first product will be a smart solar panel, codenamed 'Project Helios'.
# ---
#
# --- [Memory Consolidation Triggered] ---
# --- [New Summary: '**Updated Summary – Innovatech & Project Helios**
#
# - **Company**: Innovatech – a new sustainable‑energy venture.
# - **Mission**: “Empowering communities with affordable, clean energy solutions for a resilient future.”
# - **Primary Offerings**: Solar‑tech, energy storage, grid‑integration, bio‑energy, circular‑economy services (focus on depth over breadth).
# - **Brand & Marketing**: Green/blue palette, minimalist logo, storytelling around lab‑to‑rooftop transition.
# - **MVP outline**: Hardware (solar panels or batteries), cloud dashboard, service network, financing options (pay‑as‑you‑go, green bonds).
#
# - **First Product – Project Helios (Smart Solar Panel)**
#   - **Goal**: 5–10 % higher yield via micro‑inverter + optimizer, integrated sensors, edge‑AI, IoT connectivity, modular & eco‑friendly design.
#   - **Road‑Map (12–18 mo)**:
#     1. Concept & feasibility (market‑validated use‑cases, technical specs).
#     2. Design & prototyping (hardware + firmware).
#     3. Validation & certification (IEC/UL, field trials).
#     4. IP & legal protection (provisional patents, trademarks).
#     5. Go‑to‑market (pilot installations, pricing model, maintenance network).
#   - **Hardware stack**: 400 Wp PV cells, micro‑inverter/optimizer, STM32H7 MCU, sensors, Wi‑Fi/LoRaWAN.
#   - **Software stack**: OTA firmware, TensorFlow‑Lite‑Micro AI, AWS/Azure IoT, React‑based dashboard.
#   - **Prototype timeline**: From spec definition (month 1) to MVP launch (month 12).
#   - **Funding/Partnerships**: Seed via angel/grants, Series A cleantech VCs, utility partners, hardware supplier discounts.
#   - **Checklist**: Product spec, prototype, AI model, cloud infra, IP filing, pilot site, business model, legal entity, marketing materials.
#
# - **Next Steps Discussed**:
#   - Define pilot focus (rural off‑grid vs. urban commercial).
#   - Deep‑dive into specific tech (micro‑inverter, AI, storage integration).
#   - Pitch deck preparation and accelerator search.
#   - Utility partnership exploration.
#
# **Decision**: No concrete decisions yet beyond naming the first product; user is ready to decide on scope and technical depth. The assistant offers to drill further into any of the outlined areas.'] ---
#
# Agent > ## Project Helios – “Smart Solar Panel” Road‑Map
# *(High‑level outline to guide the first 12–18 months of development)*
#
# | **Phase** | **Goal** | **Key Deliverables** | **Milestones** |
# |-----------|----------|----------------------|----------------|
# | 1️⃣ Concept & Feasibility | Define the *unique value* Helios brings | • Market‑validated use‑cases <br>• Technical spec sheet (output, size, weight, connectivity) <br>• High‑level architecture diagram | • 1‑page executive summary <br>• 5‑minute pitch to potential stakeholders |
# | 2️⃣ Design & Prototyping | Build a working **hardware** + **software** stack | • PV cell selection (e.g., monocrystalline 400 Wp) <br>• Integrated micro‑inverter & DC‑to‑DC optimizer <br>• Temperature & irradiance sensors <br>• Edge‑AI module (e.g., micro‑controller with ML inference) <br>• Cloud API & dashboard mock‑ups | • 2–3 hardware prototypes (lab + field) <br>• Software beta (OTA updates, performance analytics) |
# | 3️⃣ Validation & Certification | Demonstrate reliability, safety & regulatory compliance | • IEC 61215, IEC 61730, UL, and local grid‑connection approvals <br>• Field test (3–6 months, >10kWh/kWp) <br>• Energy yield & efficiency comparison vs. baseline panels | • Pass all compliance tests <br>• Publish pilot case study |
# | 4️⃣ IP & Legal | Protect the innovation & brand | • Patent filing (cell‑integrated optimizer, AI algorithm) <br>• Trademarks for “Helios” & branding | • Granted provisional patent <br>• Trademark registration |
# | 5️⃣ Go‑to‑Market (GTM) | Secure first adopters & revenue stream | • Pilot program with community microgrid or commercial building <br>• Pricing model (pay‑per‑kWh or subscription) <br>• Service & maintenance network | • 1–2 pilot installations <br>• 10–20% cost savings vs. conventional PV |
#
#
# ---
#
# ### 1. What Makes Helios “Smart”?
#
# | **Feature** | **Benefit** | **Why it matters for the market** |
# |------------|-------------|------------------------------------|
# | **Integrated Micro‑Inverter + DC Optimizer** | Maximises output per panel, reduces string losses | Drives higher energy yield (5–10 % better) |
# | **Built‑in Irradiance & Temperature Sensors** | Real‑time monitoring of panel performance | Enables predictive maintenance, early fault detection |
# | **Edge‑AI (Power‑efficient inference)** | Detects shading, soiling, or degradation on the fly | Reduces downtime, lowers O&M cost |
# | **Wi‑Fi / LoRaWAN / NB‑IoT Connectivity** | Cloud‑connected dashboards & OTA firmware | Gives customers instant insights & remote control |
# | **Modular Design** | Easy to replace a single panel, scale up/down | Simplifies installation, lowers lifecycle cost |
# | **Eco‑Friendly Materials** | Low‑VOC encapsulant, recyclable glass | Meets ESG and circular‑economy criteria |
#
# ---
#
# ### 2. Hardware Stack (High‑Level)
#
# ```
# ┌───────────────────────┐
# │  PV Cell Array (400Wp)│
# ├───────────────────────┤
# │  Glass/Encapsulant    │
# ├───────────────────────┤
# │  Smart Inverter/Optimizer
# │     (12‑24 V -> 48 V)   │
# ├───────────────────────┤
# │  Edge‑AI MCU (e.g., STM32H7)│
# ├───────────────────────┤
# │  Sensor Suite (IR, temp, voltage)│
# ├───────────────────────┤
# │  Connectivity Module  │
# │   (Wi‑Fi / LoRa)      │
# └───────────────────────┘
# ```
#
# *Tip*: Consider a “single‑cell” micro‑inverter approach to keep cost per kWp below 70 ¢ while keeping panel weight < 15 kg.
#
# ---
#
# ### 3. Software Stack
#
# | Layer | Function | Example Tech Stack |
# |-------|----------|--------------------|
# | **Device** | OTA firmware, local caching | C++/Rust, ESP‑IDF, mbed |
# | **Edge AI** | Real‑time anomaly detection | TensorFlow Lite Micro, ONNX |
# | **Cloud** | Data ingestion, analytics, billing | AWS IoT Core, Azure Functions, Grafana |
# | **Dashboard** | User portal, KPI visualization | React + D3, GraphQL |
# | **API** | Integrations (grid operators, financing platforms) | REST/GraphQL, OAuth2 |
#
# ---
#
# ### 4. Prototype Development Timeline
#
# | Month | Task | Deliverable |
# |-------|------|-------------|
# | 1 | Define spec & order raw components | Technical brief |
# | 2 | PCB & enclosure design | BOM, CAD files |
# | 3 | Assemble 5 test units | Prototype A |
# | 4 | Bench‑test for power & thermal | Test report |
# | 5 | Firmware & edge‑AI algorithm | Version 1.0 |
# | 6 | Lab‑field trial (10 days) | Performance data |
# | 7 | Iterate hardware (tolerances, weight) | Prototype B |
# | 8 | Begin compliance testing | IEC/UL test plan |
# | 9 | Secure IP filing (provisional) | Patent application |
# |10 | Pilot installation kickoff | On‑site deployment |
# |12 | Full data analytics & dashboard | MVP launch |
#
# ---
#
# ### 5. Funding & Partnerships
#
# | Need | Option | Action |
# |------|--------|--------|
# | **Capital** | Series A cleantech VC | Pitch deck ready by Month 9 |
# | **Hardware** | PV cell supplier | Negotiate bulk discount after prototype |
# | **Software** | AI cloud provider | Explore AWS Graviton or Azure Sphere |
# | **Distribution** | Utility partnership | Pilot with local grid operator |
# | **Regulatory** | Testing labs | Sign contract for IEC & UL certs |
#
# ---
#
# ### 6. Quick “Helios Launch” Checklist
#
# - ☐ Finalized product spec and target market
# - ☐ Prototype hardware built and bench‑tested
# - ☐ Edge‑AI model trained on simulated shading/degradation data
# - ☐ Cloud infrastructure in place (IoT, storage, analytics)
# - ☐ Initial IP filing (provisional patent)
# - ☐ Pilot installation identified (e.g., 10kW microgrid)
# - ☐ Business model defined (subscription vs. upfront)
# - ☐ Go‑to‑market communications drafted (website, pitch deck)
# - ☐ Legal entity set up (LLC / C‑Corp)
# - ☐ Initial budget & fundraising plan
#
# ---
#
# ### Next Steps
#
# 1. **Decide Scope** – Do you want to focus on **rural off‑grid** pilots or **urban commercial** installations first?
# 2. **Tech Detail** – Would you like a deeper dive into:
#    - Micro‑inverter design
#    - Edge‑AI algorithms (e.g., CNN for defect detection)
#    - Energy storage integration
# 3. **Funding** – Need help tailoring a pitch deck or identifying cleantech accelerators?
# 4. **Partnership** – Explore utility partnership models (e.g., joint‑venture or PPAs).
#
# Let me know which area you’d like to explore first, and we’ll drill down! 🚀
# (LLM Generation Time: 3.0800 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > The marketing budget is set at $50,000.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 595
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Summary of Past Conversation:
# **Updated Summary – Innovatech & Project Helios**
#
# - **Company**: Innovatech – a new sustainable‑energy venture.
# - **Mission**: “Empowering communities with affordable, clean energy solutions for a resilient future.”
# - **Primary Offerings**: Solar‑tech, energy storage, grid‑integration, bio‑energy, circular‑economy services (focus on depth over breadth).
# - **Brand & Marketing**: Green/blue palette, minimalist logo, storytelling around lab‑to‑rooftop transition.
# - **MVP outline**: Hardware (solar panels or batteries), cloud dashboard, service network, financing options (pay‑as‑you‑go, green bonds).
#
# - **First Product – Project Helios (Smart Solar Panel)**
#   - **Goal**: 5–10 % higher yield via micro‑inverter + optimizer, integrated sensors, edge‑AI, IoT connectivity, modular & eco‑friendly design.
#   - **Road‑Map (12–18 mo)**:
#     1. Concept & feasibility (market‑validated use‑cases, technical specs).
#     2. Design & prototyping (hardware + firmware).
#     3. Validation & certification (IEC/UL, field trials).
#     4. IP & legal protection (provisional patents, trademarks).
#     5. Go‑to‑market (pilot installations, pricing model, maintenance network).
#   - **Hardware stack**: 400 Wp PV cells, micro‑inverter/optimizer, STM32H7 MCU, sensors, Wi‑Fi/LoRaWAN.
#   - **Software stack**: OTA firmware, TensorFlow‑Lite‑Micro AI, AWS/Azure IoT, React‑based dashboard.
#   - **Prototype timeline**: From spec definition (month 1) to MVP launch (month 12).
#   - **Funding/Partnerships**: Seed via angel/grants, Series A cleantech VCs, utility partners, hardware supplier discounts.
#   - **Checklist**: Product spec, prototype, AI model, cloud infra, IP filing, pilot site, business model, legal entity, marketing materials.
#
# - **Next Steps Discussed**:
#   - Define pilot focus (rural off‑grid vs. urban commercial).
#   - Deep‑dive into specific tech (micro‑inverter, AI, storage integration).
#   - Pitch deck preparation and accelerator search.
#   - Utility partnership exploration.
#
# **Decision**: No concrete decisions yet beyond naming the first product; user is ready to decide on scope and technical depth. The assistant offers to drill further into any of the outlined areas.
#
# ### Recent Messages:
#
#
# ### CURRENT REQUEST
# The marketing budget is set at $50,000.
# ---
#
# Agent > ### Quick‑Start Marketing Plan – $50 k Budget
# *(Designed for Project Helios – Smart Solar Panel)*
#
# | Category | % of Budget | Dollar Amount | Key Activities | KPI Targets |
# |----------|-------------|----------------|----------------|------------|
# | **Digital Advertising** | 40 % | **$20 k** | • Google Search & YouTube (SEO‑driven keywords: “high‑yield solar panel”, “smart solar tech”)  <br>• LinkedIn B2B campaigns (utility execs, renewable‑energy managers)  <br>• Facebook/Instagram retargeting (local homeowners, small‑business owners) | • 1 k+ qualified leads/month  <br>• Cost per lead ≤ $20  |
# | **Content & Thought Leadership** | 15 % | **$7.5 k** | • 3‑4 in‑depth white‑papers (micro‑inverter tech, edge‑AI forecasting)  <br>• 4‑6 educational blog posts + 2‑3 case‑study videos  <br>• Email nurture funnel (free downloadable “Helios ROI Calculator”) | • 2 k+ newsletter subscribers  <br>• 30% increase in website organic traffic |
# | **PR & Media Outreach** | 10 % | **$5 k** | • Press kit + media list (clean‑tech, energy‑tech, local business)  <br>• 2 × “launch day” webinars (with demo)  <br>• Sponsorship of 1 clean‑energy podcast episode | • 3‑5 earned media mentions  <br>• 1 × “Best new solar tech” award nomination |
# | **Events & Trade Shows** | 15 % | **$7.5 k** | • Booth & demo at 1‑2 regional solar‑tech expos  <br>• 1 “pilot‑site tour” event (invite local utilities & investors) | • 100+ on‑site leads  <br>• 5 pilot partnership agreements |
# | **Partnership & Influencer** | 10 % | **$5 k** | • Co‑branding with a local utility or renewable‑energy NGO  <br>• 3 micro‑influencers in sustainability space (Instagram, TikTok)  <br>• “Referrals” discount program | • 20 pilot referrals  <br>• 1 × co‑created case study |
# | **Analytics & Optimization** | 5 % | **$2.5 k** | • Google Analytics + HubSpot (or similar)  <br>• Monthly performance reviews & A/B testing | • Conversion rate lift of 20%  <br>• CAC drop of 15% |
#
# ---
#
# #### 1️⃣ Why This Mix Works
#
# | Channel | Why it matters for Helios |
# |---------|---------------------------|
# | **Digital Ads** | Targeted to both B2B (utility, commercial) and B2C (homeowners) audiences; quick lift in awareness and lead gen. |
# | **Content** | Builds technical credibility (edge‑AI, micro‑inverter) and educates on ROI – essential for a product that promises 5‑10 % yield bump. |
# | **PR** | Earned coverage amplifies the “lab‑to‑rooftop” story and taps into green‑policy circles. |
# | **Events** | Live demos & pilot‑site visits create tangible trust; key for early‑adopter utility partners. |
# | **Partnerships** | Leverage existing networks to accelerate pilot sign‑ups and credibility. |
# | **Analytics** | Continuous data‑driven tweaking ensures the $50k is spent efficiently. |
#
# ---
#
# #### 2️⃣ Implementation Timeline (12 weeks)
#
# | Week | Focus |
# |------|-------|
# | 1‑2 | Finalize creative assets, set up tracking tags, launch Google/LinkedIn campaigns. |
# | 3 | Publish first white‑paper, activate email nurture flow. |
# | 4 | Release case‑study video, push social‑media posts. |
# | 5 | Launch PR outreach, secure first media spot. |
# | 6 | Host webinar, record for on‑demand. |
# | 7 | Set up event booth (design, inventory). |
# | 8 | Travel to first trade‑show; collect leads, demo. |
# | 9 | On‑site analytics review, tweak ad spend. |
# | 10 | Activate influencer posts, send referral email blast. |
# | 11 | Close pilot agreements, gather feedback. |
# | 12 | Post‑campaign audit: metrics, learnings, next‑step budget re‑allocation. |
#
# ---
#
# #### 3️⃣ Quick‑Start Checklist
#
# | Item | Status | Next Action |
# |------|--------|--------------|
# | Brand guidelines & visual identity | ✔ | Ensure all assets match green/blue minimal palette. |
# | Landing pages (Helios overview, ROI calculator) | ✔ | Optimize for mobile & SEO. |
# | CRM + lead capture flow | ✔ | Integrate with email nurture. |
# | Media kit ready | ❌ | Prepare in 48 hrs. |
# | Pilot‑site partner list | ✔ | Schedule demo visits. |
# | Analytics dashboard (GA, HubSpot) | ✔ | Set up custom conversion goals. |
#
# ---
#
# #### 4️⃣ What to Re‑evaluate
#
# * **Target Mix** – If early pilots show stronger interest from rural off‑grid customers, shift 5 % of digital spend to Facebook/WhatsApp ads in those regions.
# * **Influencer Scale** – If the first influencer campaign yields >10 % CTR, allocate 5 % more to a micro‑influencer network.
# * **Event ROI** – Post‑expo, if booth leads convert at >15 %, consider a second event or a virtual expo next quarter.
#
# ---
#
# ### Bottom Line
#
# With a $50 k spend, you can:
#
# * Reach a broad audience (both B2B & B2C).
# * Build technical authority with content.
# * Create tangible credibility via demos and pilot showcases.
# * Keep enough slack for iterative optimization.
#
# Feel free to tweak the percentages or ask for deeper dives into any category—e.g., content calendar, ad copy ideas, or partnership outreach templates. Happy to help refine further!
# (LLM Generation Time: 2.3697 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > What is the name of my company and its first product?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 1992
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Summary of Past Conversation:
# **Updated Summary – Innovatech & Project Helios**
#
# - **Company**: Innovatech – a new sustainable‑energy venture.
# - **Mission**: “Empowering communities with affordable, clean energy solutions for a resilient future.”
# - **Primary Offerings**: Solar‑tech, energy storage, grid‑integration, bio‑energy, circular‑economy services (focus on depth over breadth).
# - **Brand & Marketing**: Green/blue palette, minimalist logo, storytelling around lab‑to‑rooftop transition.
# - **MVP outline**: Hardware (solar panels or batteries), cloud dashboard, service network, financing options (pay‑as‑you‑go, green bonds).
#
# - **First Product – Project Helios (Smart Solar Panel)**
#   - **Goal**: 5–10 % higher yield via micro‑inverter + optimizer, integrated sensors, edge‑AI, IoT connectivity, modular & eco‑friendly design.
#   - **Road‑Map (12–18 mo)**:
#     1. Concept & feasibility (market‑validated use‑cases, technical specs).
#     2. Design & prototyping (hardware + firmware).
#     3. Validation & certification (IEC/UL, field trials).
#     4. IP & legal protection (provisional patents, trademarks).
#     5. Go‑to‑market (pilot installations, pricing model, maintenance network).
#   - **Hardware stack**: 400 Wp PV cells, micro‑inverter/optimizer, STM32H7 MCU, sensors, Wi‑Fi/LoRaWAN.
#   - **Software stack**: OTA firmware, TensorFlow‑Lite‑Micro AI, AWS/Azure IoT, React‑based dashboard.
#   - **Prototype timeline**: From spec definition (month 1) to MVP launch (month 12).
#   - **Funding/Partnerships**: Seed via angel/grants, Series A cleantech VCs, utility partners, hardware supplier discounts.
#   - **Checklist**: Product spec, prototype, AI model, cloud infra, IP filing, pilot site, business model, legal entity, marketing materials.
#
# - **Next Steps Discussed**:
#   - Define pilot focus (rural off‑grid vs. urban commercial).
#   - Deep‑dive into specific tech (micro‑inverter, AI, storage integration).
#   - Pitch deck preparation and accelerator search.
#   - Utility partnership exploration.
#
# **Decision**: No concrete decisions yet beyond naming the first product; user is ready to decide on scope and technical depth. The assistant offers to drill further into any of the outlined areas.
#
# ### Recent Messages:
# User: The marketing budget is set at $50,000.
# Assistant: ### Quick‑Start Marketing Plan – $50 k Budget
# *(Designed for Project Helios – Smart Solar Panel)*
#
# | Category | % of Budget | Dollar Amount | Key Activities | KPI Targets |
# |----------|-------------|----------------|----------------|------------|
# | **Digital Advertising** | 40 % | **$20 k** | • Google Search & YouTube (SEO‑driven keywords: “high‑yield solar panel”, “smart solar tech”)  <br>• LinkedIn B2B campaigns (utility execs, renewable‑energy managers)  <br>• Facebook/Instagram retargeting (local homeowners, small‑business owners) | • 1 k+ qualified leads/month  <br>• Cost per lead ≤ $20  |
# | **Content & Thought Leadership** | 15 % | **$7.5 k** | • 3‑4 in‑depth white‑papers (micro‑inverter tech, edge‑AI forecasting)  <br>• 4‑6 educational blog posts + 2‑3 case‑study videos  <br>• Email nurture funnel (free downloadable “Helios ROI Calculator”) | • 2 k+ newsletter subscribers  <br>• 30% increase in website organic traffic |
# | **PR & Media Outreach** | 10 % | **$5 k** | • Press kit + media list (clean‑tech, energy‑tech, local business)  <br>• 2 × “launch day” webinars (with demo)  <br>• Sponsorship of 1 clean‑energy podcast episode | • 3‑5 earned media mentions  <br>• 1 × “Best new solar tech” award nomination |
# | **Events & Trade Shows** | 15 % | **$7.5 k** | • Booth & demo at 1‑2 regional solar‑tech expos  <br>• 1 “pilot‑site tour” event (invite local utilities & investors) | • 100+ on‑site leads  <br>• 5 pilot partnership agreements |
# | **Partnership & Influencer** | 10 % | **$5 k** | • Co‑branding with a local utility or renewable‑energy NGO  <br>• 3 micro‑influencers in sustainability space (Instagram, TikTok)  <br>• “Referrals” discount program | • 20 pilot referrals  <br>• 1 × co‑created case study |
# | **Analytics & Optimization** | 5 % | **$2.5 k** | • Google Analytics + HubSpot (or similar)  <br>• Monthly performance reviews & A/B testing | • Conversion rate lift of 20%  <br>• CAC drop of 15% |
#
# ---
#
# #### 1️⃣ Why This Mix Works
#
# | Channel | Why it matters for Helios |
# |---------|---------------------------|
# | **Digital Ads** | Targeted to both B2B (utility, commercial) and B2C (homeowners) audiences; quick lift in awareness and lead gen. |
# | **Content** | Builds technical credibility (edge‑AI, micro‑inverter) and educates on ROI – essential for a product that promises 5‑10 % yield bump. |
# | **PR** | Earned coverage amplifies the “lab‑to‑rooftop” story and taps into green‑policy circles. |
# | **Events** | Live demos & pilot‑site visits create tangible trust; key for early‑adopter utility partners. |
# | **Partnerships** | Leverage existing networks to accelerate pilot sign‑ups and credibility. |
# | **Analytics** | Continuous data‑driven tweaking ensures the $50k is spent efficiently. |
#
# ---
#
# #### 2️⃣ Implementation Timeline (12 weeks)
#
# | Week | Focus |
# |------|-------|
# | 1‑2 | Finalize creative assets, set up tracking tags, launch Google/LinkedIn campaigns. |
# | 3 | Publish first white‑paper, activate email nurture flow. |
# | 4 | Release case‑study video, push social‑media posts. |
# | 5 | Launch PR outreach, secure first media spot. |
# | 6 | Host webinar, record for on‑demand. |
# | 7 | Set up event booth (design, inventory). |
# | 8 | Travel to first trade‑show; collect leads, demo. |
# | 9 | On‑site analytics review, tweak ad spend. |
# | 10 | Activate influencer posts, send referral email blast. |
# | 11 | Close pilot agreements, gather feedback. |
# | 12 | Post‑campaign audit: metrics, learnings, next‑step budget re‑allocation. |
#
# ---
#
# #### 3️⃣ Quick‑Start Checklist
#
# | Item | Status | Next Action |
# |------|--------|--------------|
# | Brand guidelines & visual identity | ✔ | Ensure all assets match green/blue minimal palette. |
# | Landing pages (Helios overview, ROI calculator) | ✔ | Optimize for mobile & SEO. |
# | CRM + lead capture flow | ✔ | Integrate with email nurture. |
# | Media kit ready | ❌ | Prepare in 48 hrs. |
# | Pilot‑site partner list | ✔ | Schedule demo visits. |
# | Analytics dashboard (GA, HubSpot) | ✔ | Set up custom conversion goals. |
#
# ---
#
# #### 4️⃣ What to Re‑evaluate
#
# * **Target Mix** – If early pilots show stronger interest from rural off‑grid customers, shift 5 % of digital spend to Facebook/WhatsApp ads in those regions.
# * **Influencer Scale** – If the first influencer campaign yields >10 % CTR, allocate 5 % more to a micro‑influencer network.
# * **Event ROI** – Post‑expo, if booth leads convert at >15 %, consider a second event or a virtual expo next quarter.
#
# ---
#
# ### Bottom Line
#
# With a $50 k spend, you can:
#
# * Reach a broad audience (both B2B & B2C).
# * Build technical authority with content.
# * Create tangible credibility via demos and pilot showcases.
# * Keep enough slack for iterative optimization.
#
# Feel free to tweak the percentages or ask for deeper dives into any category—e.g., content calendar, ad copy ideas, or partnership outreach templates. Happy to help refine further!
#
# ### CURRENT REQUEST
# What is the name of my company and its first product?
# ---
#
# --- [Memory Consolidation Triggered] ---
# --- [New Summary: '**Updated Summary – Innovatech & Project Helios**
#
# | Topic | Details |
# |-------|---------|
# | **Company** | Innovatech – a new sustainable‑energy venture focused on “empowering communities with affordable, clean energy.” |
# | **Mission & Brand** | Green‑blue minimalist visual identity, storytelling from “lab‑to‑rooftop.” |
# | **Core Offerings** | Solar‑tech, energy storage, grid integration, bio‑energy, circular‑economy services – depth over breadth. |
# | **First Product** | **Project Helios** – a smart, 400 Wp solar panel with micro‑inverter + optimizer, edge‑AI forecasting, IoT connectivity, modular eco‑design. |
# | **Tech Stack** | Hardware: STM32H7 MCU, sensors, Wi‑Fi/LoRaWAN. Software: OTA firmware, TensorFlow‑Lite‑Micro AI, AWS/Azure IoT, React dashboard. |
# | **Road‑Map (12–18 mo)** | 1) Concept & feasibility, 2) Design/prototype, 3) Validation/certification, 4) IP/legal, 5) Go‑to‑market (pilots, pricing, maintenance). |
# | **Funding/Partnerships** | Seed via angel/grants, Series A cleantech VCs, utility partners, hardware supplier discounts. |
# | **Marketing Budget** | $50 k allocated across:  |
# |  | • Digital ads (40 %) – $20 k → Google/YouTube, LinkedIn, Facebook/Instagram retargeting (goal 1k+ qualified leads/month, CPL ≤ $20). |
# |  | • Content & thought leadership (15 %) – $7.5 k → white‑papers, blogs, ROI calculator (2k+ newsletter subs, 30% traffic lift). |
# |  | • PR & media outreach (10 %) – $5 k → press kit, webinars, podcast sponsorship (3–5 earned mentions, award nomination). |
# |  | • Events & trade shows (15 %) – $7.5 k → 1–2 expos, pilot‑site tour (100+ on‑site leads, 5 partnership deals). |
# |  | • Partnerships & influencers (10 %) – $5 k → co‑branding with utilities/NGOs, micro‑influencers, referral program (20 pilot referrals, 1 co‑created case study). |
# |  | • Analytics & optimization (5 %) – $2.5 k → GA/HubSpot, A/B testing (20% conversion lift, 15% CAC drop). |
# | **Implementation Timeline** | 12‑week rollout: weeks 1‑2 launch ads, week 3 white‑paper, week 5 PR outreach, week 7 event prep, weeks 8‑9 lead collection, week 11 close pilots, week 12 audit & learnings. |
# | **Checklist Status** | Brand, landing pages, CRM, analytics – ✅. Media kit – ❌ (to prepare in 48 hrs). |
# | **Next Steps Discussed** | • Define pilot focus (rural off‑grid vs. urban commercial). • Deep‑dive into micro‑inverter, AI, storage tech. • Pitch deck and accelerator search. • Utility partnership exploration. |
# | **Decision** | Company name confirmed as Innovatech; first product is Project Helios. No further concrete decisions made; marketing plan ready for execution. |
#
# This summary captures all key facts, names, plans, and outstanding items from the conversation.'] ---
#
# Agent > **Company name:** Innovatech
# **First product:** Project Helios – the Smart Solar Panel.
# (LLM Generation Time: 0.4458 seconds)
# ======================================================================
# Summarization memory cleared.

# %% [markdown]
# ### Strategy 4: Retrieval-Based Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Long-term recall, precision needed                   | Harder to implement, needs vector DB + ranking         |
#
# **Theory:** This is a powerful and widely-used strategy, forming the basis of Retrieval-Augmented Generation (RAG). Instead of storing conversation history linearly, each piece of information (e.g., a conversational turn) is treated as a document in a searchable database. When the user asks a new question, the system:
# 1.  Converts the user's query into a numerical vector (an embedding).
# 2.  Searches the database to find the `k` most semantically similar document embeddings.
# 3.  Retrieves the original text of these documents.
# 4.  Injects this retrieved text into the LLM's context.
#
# This allows the agent to pull in relevant information from any point in the past, no matter how long ago. We use `faiss` to create an efficient, in-memory vector index.

# %%
# Import necessary libraries for numerical operations and similarity search.
import numpy as np
import faiss

# --- Strategy 4: Retrieval-Based Memory ---
# This strategy treats each piece of conversation as a document in a searchable
# database. It uses vector embeddings to find and retrieve the most semantically
# relevant pieces of information from the past to answer a new query. This is the
# core concept behind Retrieval-Augmented Generation (RAG).
class RetrievalMemory(BaseMemoryStrategy):
    def __init__(self, k: int = 2, embedding_dim: int = 3584):
        """
        Initializes the retrieval memory system.
        
        Args:
            k: The number of top relevant documents to retrieve for a given query.
            embedding_dim: The dimension of the vectors generated by the embedding model.
                           For BAAI/bge-multilingual-gemma2, this is 3584.
        """
        # The number of nearest neighbors to retrieve.
        self.k = k
        # The dimensionality of the embedding vectors. Must match the model's output.
        self.embedding_dim = embedding_dim
        # A list to store the original text content of each document.
        self.documents = []
        # Initialize a FAISS index. IndexFlatL2 performs an exhaustive search using
        # L2 (Euclidean) distance, which is effective for a moderate number of vectors.
        self.index = faiss.IndexFlatL2(self.embedding_dim)

    def add_message(self, user_input: str, ai_response: str):
        """
        Adds a new conversational turn to the memory. Each part of the turn (user
        input and AI response) is embedded and indexed separately for granular retrieval.
        """
        # We store each part of the turn as a separate document to allow for more
        # precise matching. For example, a query might be similar to a past user
        # statement but not the AI's response in that same turn.
        docs_to_add = [
            f"User said: {user_input}",
            f"AI responded: {ai_response}"
        ]
        for doc in docs_to_add:
            # Generate a numerical vector representation of the document.
            embedding = generate_embedding(doc)
            # Proceed only if the embedding was successfully created.
            if embedding:
                # Store the original text. The index of this document will correspond
                # to the index of its vector in the FAISS index.
                self.documents.append(doc)
                # FAISS requires the input vectors to be a 2D numpy array of float32.
                vector = np.array([embedding], dtype='float32')
                # Add the vector to the FAISS index, making it searchable.
                self.index.add(vector)

    def get_context(self, query: str) -> str:
        """
        Finds the k most relevant documents from memory based on semantic
        similarity to the user's query.
        """
        # If the index has no vectors, there's nothing to search.
        if self.index.ntotal == 0:
            return "No information in memory yet."
        
        # Convert the user's query into an embedding vector.
        query_embedding = generate_embedding(query)
        if not query_embedding:
            return "Could not process query for retrieval."
        
        # Convert the query embedding into the format required by FAISS.
        query_vector = np.array([query_embedding], dtype='float32')
        
        # Perform the search. 'search' returns the distances and the indices
        # of the k nearest neighbors to the query vector.
        distances, indices = self.index.search(query_vector, self.k)
        
        # Use the returned indices to retrieve the original text documents.
        # We check for `i != -1` as FAISS can return -1 for invalid indices.
        retrieved_docs = [self.documents[i] for i in indices[0] if i != -1]
        
        if not retrieved_docs:
            return "Could not find any relevant information in memory."
        
        # Format the retrieved documents into a string to be used as context.
        return "### Relevant Information Retrieved from Memory:\n" + "\n---\n".join(retrieved_docs)

    def clear(self):
        """Resets the memory completely by clearing the documents and the FAISS index."""
        self.documents = []
        self.index.reset()
        print("Retrieval memory (documents and FAISS index) cleared.")

# %% [markdown]
# #### Demonstration of Retrieval Memory
#
# **What to watch for:** We will have a conversation about two completely different topics: a vacation plan and a software project. Then, we will ask a question about the vacation. The debug output will show that only the relevant vacation-related documents are retrieved and injected into the prompt, completely ignoring the irrelevant project talk.

# %%
# Initialize the RetrievalMemory with k=2, meaning it will retrieve the top 2 most relevant documents.
retrieval_memory = RetrievalMemory(k=2, embedding_dim=768)
# Create an AIAgent and inject the retrieval memory strategy.
agent = AIAgent(memory_strategy=retrieval_memory)

# --- Start the conversation with mixed topics ---
# First turn: Discussing a vacation plan. This will be stored as a document.
agent.chat("I am planning a vacation to Japan for next spring.")
# Second turn: Discussing a software project. This will also be stored as a separate document.
agent.chat("For my software project, I'm using the React framework for the frontend.")
# Third turn: More details about the vacation.
agent.chat("I want to visit Tokyo and Kyoto while I'm on my trip.")
# Fourth turn: More details about the software project.
agent.chat("The backend of my project will be built with Django.")

# --- Test the retrieval mechanism ---
# Now, ask a question specifically about the vacation.
# The agent will convert this query into an embedding and search the memory.
# It should find that the documents about Japan, Tokyo, and Kyoto are semantically
# closer to the query than the documents about React and Django.
agent.chat("What cities am I planning to visit on my vacation?")
# The agent should retrieve the Japan/Tokyo/Kyoto info and ignore the software project info.

# Clean up the memory for the next demonstration.
retrieval_memory.clear()
# Out:
# Agent initialized with RetrievalMemory.
#
# ========================= NEW INTERACTION =========================
# User > I am planning a vacation to Japan for next spring.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 32
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# No information in memory yet.
#
# ### CURRENT REQUEST
# I am planning a vacation to Japan for next spring.
# ---
#
# Agent > That’s exciting! Spring is a fantastic time to visit Japan—cherry blossoms, pleasant weather, and a ton of festivals.
# To help you plan the best trip, could you share a bit more about:
#
# | What you’d like to know | Why it matters |
# |------------------------|----------------|
# | **Length of stay** | Determines how many places you can realistically cover. |
# | **Budget range** | Helps tailor accommodation, dining, and transport options. |
# | **Travel dates (or rough window)** | Cherry‑blossom peak varies by region. |
# | **Interests** (history, nature, food, pop culture, etc.) | Lets me suggest specific cities or activities. |
# | **Travel style** (solo, couple, family, backpacker, luxury, etc.) | Affects accommodation and itinerary pacing. |
#
# While you think about those details, here’s a quick snapshot of what to expect in spring (March‑May):
#
# ---
#
# ## 1. Cherry‑Blossom (Sakura) Highlights
#
# | Region | Typical Bloom Window | Must‑See Spots |
# |--------|----------------------|----------------|
# | **Tokyo / Yokohama** | Mid‑March to early April | Ueno Park, Chidorigafuchi, Yoyogi Park |
# | **Kyoto** | Early to mid‑April | Maruyama Park, Philosopher’s Path, Kiyomizu‑dera |
# | **Hiroshima / Miyajima** | Mid‑April | Peace Memorial Park, Itsukushima Shrine |
# | **Hokkaido** | Late April to early May | Matsumae Park, Furano (also flower fields) |
#
# *Tip:* Check the **Japan Meteorological Agency’s Sakura Forecast** a few months before your trip to time your arrival with peak blossoms.
#
# ---
#
# ## 2. Seasonal Events & Festivals
#
# | Event | When | Where | Why it’s worth it |
# |-------|------|-------|-------------------|
# | **Sakura Matsuri (Cherry Blossom Festivals)** | Throughout spring | All major parks | Traditional food stalls, music, and scenic walks |
# | **Takayama Spring Festival** | March 20–21 | Takayama (Gifu Prefecture) | Beautiful floats, local crafts |
# | **Sapporo White Illumination** | Late March | Sapporo | Stunning winter lights that linger into early spring |
# | **Hakone Fireworks** | Mid‑May | Hakone | Gorgeous fireworks over the lake |
#
# ---
#
# ## 3. Sample 10‑Day Itinerary (Mid‑April)
#
# | Day | City | Highlights |
# |-----|------|------------|
# | 1–3 | **Tokyo** | Shibuya, Asakusa, Ueno Park cherry trees, Tsukiji Market, Akihabara |
# | 4 | **Day trip to Nikko** | Toshogu Shrine, natural scenery |
# | 5–6 | **Kyoto** | Fushimi Inari, Kiyomizu‑dera, Arashiyama Bamboo Grove, Gion walks |
# | 7 | **Nara** | Todai‑ji, Nara Park (deer), Kasuga Taisha |
# | 8 | **Osaka** | Dotonbori, Osaka Castle, Umeda Sky Building |
# | 9 | **Hiroshima** | Peace Memorial Park, Miyajima Island |
# | 10 | **Return to Tokyo or Osaka for departure** | Souvenir shopping, last‑minute sights |
#
# *Adjust the order and duration based on your interests.*
#
# ---
#
# ## 4. Practical Travel Tips
#
# | Topic | Key Points |
# |-------|------------|
# | **Flights** | Look for early‑bargain deals mid‑year (June‑July). Major hubs: Narita (Tokyo), Haneda (Tokyo), Kansai (Osaka), and Chubu (Nagoya). |
# | **Rail Pass** | If you’re covering multiple cities, the **Japan Rail Pass (JR Pass)** can save money. Buy the pass before arriving in Japan. |
# | **Accommodation** | Mix of **business hotels** (budget) and **ryokans** (traditional inns). Book well in advance for cherry‑blossom season. |
# | **Language** | English signage is common in cities; a pocket phrasebook or translation app helps in rural areas. |
# | **Money** | Cash is king in Japan. ATMs in 7‑Eleven and post offices accept foreign cards. |
# | **Weather** | Layered clothing; spring can be chilly in the mornings (especially in northern regions). |
# | **Health** | Check vaccination requirements and travel insurance. |
#
# ---
#
# ## 5. Visa & Entry Requirements
#
# - **Tourist visas**: Citizens of many countries can enter Japan visa‑exempt for up to 90 days. Check your home country’s specific rules.
# - **COVID‑19**: As of now, no restrictions, but keep an eye on updates from the Japanese embassy.
# - **Travel insurance**: Highly recommended.
#
# ---
#
# ### Next Steps
#
# 1. **Set your dates** – Try to catch the early‑April bloom in Tokyo or Kyoto.
# 2. **Decide on length** – A 10‑12 day trip lets you hit multiple highlights while staying relaxed.
# 3. **Draft a rough budget** – Roughly ¥120–¥150k (~$900–$1,200) per person for a mid‑range trip (excluding flights).
# 4. **Book flights & accommodations early** – Prices spike during the Sakura season.
#
# Whenever you’re ready, let me know your answers to the questions above, and I can craft a more tailored itinerary and provide booking recommendations. Safe travels! 🌸✈️
# (LLM Generation Time: 2.6387 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > For my software project, I'm using the React framework for the frontend.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 1.0528 seconds
# Estimated Prompt Tokens: 1259
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Relevant Information Retrieved from Memory:
# User said: I am planning a vacation to Japan for next spring.
# ---
# AI responded: That’s exciting! Spring is a fantastic time to visit Japan—cherry blossoms, pleasant weather, and a ton of festivals.
# To help you plan the best trip, could you share a bit more about:
#
# | What you’d like to know | Why it matters |
# |------------------------|----------------|
# | **Length of stay** | Determines how many places you can realistically cover. |
# | **Budget range** | Helps tailor accommodation, dining, and transport options. |
# | **Travel dates (or rough window)** | Cherry‑blossom peak varies by region. |
# | **Interests** (history, nature, food, pop culture, etc.) | Lets me suggest specific cities or activities. |
# | **Travel style** (solo, couple, family, backpacker, luxury, etc.) | Affects accommodation and itinerary pacing. |
#
# While you think about those details, here’s a quick snapshot of what to expect in spring (March‑May):
#
# ---
#
# ## 1. Cherry‑Blossom (Sakura) Highlights
#
# | Region | Typical Bloom Window | Must‑See Spots |
# |--------|----------------------|----------------|
# | **Tokyo / Yokohama** | Mid‑March to early April | Ueno Park, Chidorigafuchi, Yoyogi Park |
# | **Kyoto** | Early to mid‑April | Maruyama Park, Philosopher’s Path, Kiyomizu‑dera |
# | **Hiroshima / Miyajima** | Mid‑April | Peace Memorial Park, Itsukushima Shrine |
# | **Hokkaido** | Late April to early May | Matsumae Park, Furano (also flower fields) |
#
# *Tip:* Check the **Japan Meteorological Agency’s Sakura Forecast** a few months before your trip to time your arrival with peak blossoms.
#
# ---
#
# ## 2. Seasonal Events & Festivals
#
# | Event | When | Where | Why it’s worth it |
# |-------|------|-------|-------------------|
# | **Sakura Matsuri (Cherry Blossom Festivals)** | Throughout spring | All major parks | Traditional food stalls, music, and scenic walks |
# | **Takayama Spring Festival** | March 20–21 | Takayama (Gifu Prefecture) | Beautiful floats, local crafts |
# | **Sapporo White Illumination** | Late March | Sapporo | Stunning winter lights that linger into early spring |
# | **Hakone Fireworks** | Mid‑May | Hakone | Gorgeous fireworks over the lake |
#
# ---
#
# ## 3. Sample 10‑Day Itinerary (Mid‑April)
#
# | Day | City | Highlights |
# |-----|------|------------|
# | 1–3 | **Tokyo** | Shibuya, Asakusa, Ueno Park cherry trees, Tsukiji Market, Akihabara |
# | 4 | **Day trip to Nikko** | Toshogu Shrine, natural scenery |
# | 5–6 | **Kyoto** | Fushimi Inari, Kiyomizu‑dera, Arashiyama Bamboo Grove, Gion walks |
# | 7 | **Nara** | Todai‑ji, Nara Park (deer), Kasuga Taisha |
# | 8 | **Osaka** | Dotonbori, Osaka Castle, Umeda Sky Building |
# | 9 | **Hiroshima** | Peace Memorial Park, Miyajima Island |
# | 10 | **Return to Tokyo or Osaka for departure** | Souvenir shopping, last‑minute sights |
#
# *Adjust the order and duration based on your interests.*
#
# ---
#
# ## 4. Practical Travel Tips
#
# | Topic | Key Points |
# |-------|------------|
# | **Flights** | Look for early‑bargain deals mid‑year (June‑July). Major hubs: Narita (Tokyo), Haneda (Tokyo), Kansai (Osaka), and Chubu (Nagoya). |
# | **Rail Pass** | If you’re covering multiple cities, the **Japan Rail Pass (JR Pass)** can save money. Buy the pass before arriving in Japan. |
# | **Accommodation** | Mix of **business hotels** (budget) and **ryokans** (traditional inns). Book well in advance for cherry‑blossom season. |
# | **Language** | English signage is common in cities; a pocket phrasebook or translation app helps in rural areas. |
# | **Money** | Cash is king in Japan. ATMs in 7‑Eleven and post offices accept foreign cards. |
# | **Weather** | Layered clothing; spring can be chilly in the mornings (especially in northern regions). |
# | **Health** | Check vaccination requirements and travel insurance. |
#
# ---
#
# ## 5. Visa & Entry Requirements
#
# - **Tourist visas**: Citizens of many countries can enter Japan visa‑exempt for up to 90 days. Check your home country’s specific rules.
# - **COVID‑19**: As of now, no restrictions, but keep an eye on updates from the Japanese embassy.
# - **Travel insurance**: Highly recommended.
#
# ---
#
# ### Next Steps
#
# 1. **Set your dates** – Try to catch the early‑April bloom in Tokyo or Kyoto.
# 2. **Decide on length** – A 10‑12 day trip lets you hit multiple highlights while staying relaxed.
# 3. **Draft a rough budget** – Roughly ¥120–¥150k (~$900–$1,200) per person for a mid‑range trip (excluding flights).
# 4. **Book flights & accommodations early** – Prices spike during the Sakura season.
#
# Whenever you’re ready, let me know your answers to the questions above, and I can craft a more tailored itinerary and provide booking recommendations. Safe travels! 🌸✈️
#
# ### CURRENT REQUEST
# For my software project, I'm using the React framework for the frontend.
# ---
#
# Agent > Sounds great! 🎉 React is a powerful tool for building dynamic UIs.
# To help you out, could you share a bit more about what you’re looking for? Here are some common areas people usually want guidance on:
#
# | Topic | Typical question | Why it matters |
# |-------|------------------|----------------|
# | **Project setup** | “How do I bootstrap a clean React app with TypeScript, Vite, or Create‑React‑App?” | A solid foundation saves headaches later. |
# | **State management** | “When to use Context + useReducer vs. Redux Toolkit vs. Zustand?” | Picking the right pattern keeps state predictable and maintainable. |
# | **Routing** | “How do I handle nested routes, auth guards, or dynamic imports with React Router v6?” | Smooth navigation is key to a great user experience. |
# | **Styling** | “What’s the best approach: CSS‑in‑JS (styled‑components), Tailwind, or SCSS modules?” | Consistency and scalability in styling affect future refactoring. |
# | **Testing** | “How do I set up unit, integration, and E2E tests (Jest, React Testing Library, Cypress)? ” | Robust tests improve reliability and developer confidence. |
# | **Performance** | “What techniques can I use to lazy‑load components or memoize expensive renders?” | Helps keep the app snappy, especially on mobile. |
# | **Deployment** | “How do I deploy to Netlify, Vercel, or a custom server?” | Seamless CI/CD pipelines reduce downtime. |
# | **TypeScript** | “What’s a good way to type component props, hooks, or context?” | Strong types catch bugs early. |
#
# Feel free to pick a topic (or list multiple), or just let me know the biggest pain point you’re facing right now. Once I know where you’re at, I can drop a tailored snippet, a step‑by‑step guide, or even a small project structure example. 🚀
# (LLM Generation Time: 0.9201 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > I want to visit Tokyo and Kyoto while I'm on my trip.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 1.0909 seconds
# Estimated Prompt Tokens: 1258
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Relevant Information Retrieved from Memory:
# User said: I am planning a vacation to Japan for next spring.
# ---
# AI responded: That’s exciting! Spring is a fantastic time to visit Japan—cherry blossoms, pleasant weather, and a ton of festivals.
# To help you plan the best trip, could you share a bit more about:
#
# | What you’d like to know | Why it matters |
# |------------------------|----------------|
# | **Length of stay** | Determines how many places you can realistically cover. |
# | **Budget range** | Helps tailor accommodation, dining, and transport options. |
# | **Travel dates (or rough window)** | Cherry‑blossom peak varies by region. |
# | **Interests** (history, nature, food, pop culture, etc.) | Lets me suggest specific cities or activities. |
# | **Travel style** (solo, couple, family, backpacker, luxury, etc.) | Affects accommodation and itinerary pacing. |
#
# While you think about those details, here’s a quick snapshot of what to expect in spring (March‑May):
#
# ---
#
# ## 1. Cherry‑Blossom (Sakura) Highlights
#
# | Region | Typical Bloom Window | Must‑See Spots |
# |--------|----------------------|----------------|
# | **Tokyo / Yokohama** | Mid‑March to early April | Ueno Park, Chidorigafuchi, Yoyogi Park |
# | **Kyoto** | Early to mid‑April | Maruyama Park, Philosopher’s Path, Kiyomizu‑dera |
# | **Hiroshima / Miyajima** | Mid‑April | Peace Memorial Park, Itsukushima Shrine |
# | **Hokkaido** | Late April to early May | Matsumae Park, Furano (also flower fields) |
#
# *Tip:* Check the **Japan Meteorological Agency’s Sakura Forecast** a few months before your trip to time your arrival with peak blossoms.
#
# ---
#
# ## 2. Seasonal Events & Festivals
#
# | Event | When | Where | Why it’s worth it |
# |-------|------|-------|-------------------|
# | **Sakura Matsuri (Cherry Blossom Festivals)** | Throughout spring | All major parks | Traditional food stalls, music, and scenic walks |
# | **Takayama Spring Festival** | March 20–21 | Takayama (Gifu Prefecture) | Beautiful floats, local crafts |
# | **Sapporo White Illumination** | Late March | Sapporo | Stunning winter lights that linger into early spring |
# | **Hakone Fireworks** | Mid‑May | Hakone | Gorgeous fireworks over the lake |
#
# ---
#
# ## 3. Sample 10‑Day Itinerary (Mid‑April)
#
# | Day | City | Highlights |
# |-----|------|------------|
# | 1–3 | **Tokyo** | Shibuya, Asakusa, Ueno Park cherry trees, Tsukiji Market, Akihabara |
# | 4 | **Day trip to Nikko** | Toshogu Shrine, natural scenery |
# | 5–6 | **Kyoto** | Fushimi Inari, Kiyomizu‑dera, Arashiyama Bamboo Grove, Gion walks |
# | 7 | **Nara** | Todai‑ji, Nara Park (deer), Kasuga Taisha |
# | 8 | **Osaka** | Dotonbori, Osaka Castle, Umeda Sky Building |
# | 9 | **Hiroshima** | Peace Memorial Park, Miyajima Island |
# | 10 | **Return to Tokyo or Osaka for departure** | Souvenir shopping, last‑minute sights |
#
# *Adjust the order and duration based on your interests.*
#
# ---
#
# ## 4. Practical Travel Tips
#
# | Topic | Key Points |
# |-------|------------|
# | **Flights** | Look for early‑bargain deals mid‑year (June‑July). Major hubs: Narita (Tokyo), Haneda (Tokyo), Kansai (Osaka), and Chubu (Nagoya). |
# | **Rail Pass** | If you’re covering multiple cities, the **Japan Rail Pass (JR Pass)** can save money. Buy the pass before arriving in Japan. |
# | **Accommodation** | Mix of **business hotels** (budget) and **ryokans** (traditional inns). Book well in advance for cherry‑blossom season. |
# | **Language** | English signage is common in cities; a pocket phrasebook or translation app helps in rural areas. |
# | **Money** | Cash is king in Japan. ATMs in 7‑Eleven and post offices accept foreign cards. |
# | **Weather** | Layered clothing; spring can be chilly in the mornings (especially in northern regions). |
# | **Health** | Check vaccination requirements and travel insurance. |
#
# ---
#
# ## 5. Visa & Entry Requirements
#
# - **Tourist visas**: Citizens of many countries can enter Japan visa‑exempt for up to 90 days. Check your home country’s specific rules.
# - **COVID‑19**: As of now, no restrictions, but keep an eye on updates from the Japanese embassy.
# - **Travel insurance**: Highly recommended.
#
# ---
#
# ### Next Steps
#
# 1. **Set your dates** – Try to catch the early‑April bloom in Tokyo or Kyoto.
# 2. **Decide on length** – A 10‑12 day trip lets you hit multiple highlights while staying relaxed.
# 3. **Draft a rough budget** – Roughly ¥120–¥150k (~$900–$1,200) per person for a mid‑range trip (excluding flights).
# 4. **Book flights & accommodations early** – Prices spike during the Sakura season.
#
# Whenever you’re ready, let me know your answers to the questions above, and I can craft a more tailored itinerary and provide booking recommendations. Safe travels! 🌸✈️
#
# ### CURRENT REQUEST
# I want to visit Tokyo and Kyoto while I'm on my trip.
# ---
#
# Agent > Great! Tokyo and Kyoto are a classic combo that lets you experience Japan’s ultramodern buzz side‑by‑side with its ancient charm. Below is a **sample 7‑ or 10‑day outline** that focuses on those two cities while leaving a little room for a quick detour (Nara, Osaka, or even a day trip from Tokyo). Feel free to tweak the number of days, the pace, and the activities to match your own interests or travel style.
#
# ---
#
# ## 1️⃣ 7‑Day “Tokyo + Kyoto” Itinerary (Spring)
#
# | Day | City | Highlights | Why it matters |
# |-----|------|------------|----------------|
# | **1** | **Tokyo** | Arrive, check‑in, explore Shibuya & Shinjuku | First impressions, iconic cityscape |
# | **2** | **Tokyo** | Ueno Park (sakura), Ameya‑Yokochō market, Asakusa (Senso‑ji) | Cherry trees + historic vibes |
# | **3** | **Tokyo** | Meiji‑Jingu, Harajuku, Omotesandō, Harajuku’s Takeshita‑dori, evening in Roppongi | Blend of tradition & pop culture |
# | **4** | **Kyoto** | Shinkansen (approx 2.5 h) → check‑in → Gion district | Scenic ride, “old Japan” atmosphere |
# | **5** | **Kyoto** | Kiyomizu‑dera, Higashiyama, Philosopher’s Path (sakura if timing is right) | Classic temple + scenic walk |
# | **6** | **Kyoto** | Arashiyama Bamboo Grove, Tenryū‑ji, Nara (optional 1‑hr train) | Nature, deer, historic temples |
# | **7** | **Kyoto / Tokyo** | Return to Tokyo via Shinkansen (if flight out of Tokyo) or fly out from Kansai | Final day for shopping or last sights |
#
# **Key Tips for a 7‑Day Run‑Through**
#
# 1. **Shinkansen Ticket** – Buy a 7‑day JR Pass (or a limited‑use pass for the Tokaido line). It covers the Tokyo‑Kyoto leg and local JR lines in each city.
# 2. **Accommodation** – In Tokyo, pick a centrally located **business hotel** or a **short‑stay Ryokan** in the Shinjuku or Ginza area for a taste of tradition. In Kyoto, stay in a **traditional machiya** or a mid‑range hotel near the Kyoto Station or Gion.
# 3. **Sakura Timing** – Aim to hit Ueno in early‑April or mid‑April for the best bloom window. In Kyoto, early‑mid‑April is ideal for the Philosopher’s Path and Maruyama Park.
# 4. **Transport within Cities** – A prepaid **Suica/NFC card** works on most trains, subways, and buses. Consider a daily or 3‑day pass if you’ll be hopping around.
#
# ---
#
# ## 2️⃣ 10‑Day “Tokyo + Kyoto” Itinerary (with a Bonus Day)
#
# If you’d rather have a bit more breathing room and perhaps a side‑trip, extend the plan to 10 days. The layout below basically mirrors the 7‑day version but adds a dedicated day in **Osaka** (or Nara) and a return to Tokyo for departure.
#
# | Day | City | Highlights |
# |-----|------|------------|
# | 1–3 | **Tokyo** | Shibuya, Ueno Park, Asakusa, Akihabara, Tsukiji Market, Tokyo Tower |
# | 4 | **Day‑trip** | Nikko or Hakone (optional) |
# | 5–6 | **Kyoto** | Kiyomizu‑dera, Arashiyama, Fushimi Inari, Nijo‑Castle |
# | 7 | **Osaka** | Dotonbori, Osaka Castle, Umeda Sky Building |
# | 8 | **Hiroshima** | Peace Memorial Park (optional if time allows) |
# | 9 | **Kyoto/Tokyo** | Last‑minute sights or shopping |
# | 10 | **Departure** | Fly out of Tokyo or Kansai |
#
# ---
#
# ## 3️⃣ Practical “On‑The‑Go” Checklist
#
# | Item | Details |
# |------|---------|
# | **Flight** | Book a few months in advance. Look for “early‑bargain” fares in June–July. |
# | **Rail Pass** | 7‑day or 14‑day JR Pass is usually cheaper than buying individual tickets if you’ll travel back and forth. |
# | **Accommodation** | Book as soon as you have dates—especially in spring, hotels fill up fast. |
# | **Weather** | Layered outfits; morning dew in Kyoto can be cooler. |
# | **Cash** | Keep a ¥10,000‑¥20,000 balance in yen (ATM at 7‑Eleven or post office). |
# | **Language** | English signage is abundant in major cities. For rural or older temples, a phrasebook or translation app helps. |
#
# ---
#
# ### 🎯 Next Steps for You
#
# 1. **Tell me** how many days you plan to stay, or what dates you’re considering (mid‑April? early May?) so I can fine‑tune the bloom windows.
# 2. **Mention** if you’d prefer a more relaxed or a “tight‑packed” itinerary, and whether you’re traveling solo, as a couple, or with a group.
# 3. **Budget**—A mid‑range trip averages ¥120–150k per person (≈$900–$1,200) excluding flights. Let me know if you want a budget‑friendly or luxury‑style version.
#
# Once you share a few of those details, I can suggest flight options, hotel links, and any must‑book experiences (e.g., a *tea ceremony* or a *sakura viewing* event).
#
# Happy planning! 🌸✈️
# (LLM Generation Time: 2.0096 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > The backend of my project will be built with Django.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 1.0211 seconds
# Estimated Prompt Tokens: 476
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Relevant Information Retrieved from Memory:
# User said: For my software project, I'm using the React framework for the frontend.
# ---
# AI responded: Sounds great! 🎉 React is a powerful tool for building dynamic UIs.
# To help you out, could you share a bit more about what you’re looking for? Here are some common areas people usually want guidance on:
#
# | Topic | Typical question | Why it matters |
# |-------|------------------|----------------|
# | **Project setup** | “How do I bootstrap a clean React app with TypeScript, Vite, or Create‑React‑App?” | A solid foundation saves headaches later. |
# | **State management** | “When to use Context + useReducer vs. Redux Toolkit vs. Zustand?” | Picking the right pattern keeps state predictable and maintainable. |
# | **Routing** | “How do I handle nested routes, auth guards, or dynamic imports with React Router v6?” | Smooth navigation is key to a great user experience. |
# | **Styling** | “What’s the best approach: CSS‑in‑JS (styled‑components), Tailwind, or SCSS modules?” | Consistency and scalability in styling affect future refactoring. |
# | **Testing** | “How do I set up unit, integration, and E2E tests (Jest, React Testing Library, Cypress)? ” | Robust tests improve reliability and developer confidence. |
# | **Performance** | “What techniques can I use to lazy‑load components or memoize expensive renders?” | Helps keep the app snappy, especially on mobile. |
# | **Deployment** | “How do I deploy to Netlify, Vercel, or a custom server?” | Seamless CI/CD pipelines reduce downtime. |
# | **TypeScript** | “What’s a good way to type component props, hooks, or context?” | Strong types catch bugs early. |
#
# Feel free to pick a topic (or list multiple), or just let me know the biggest pain point you’re facing right now. Once I know where you’re at, I can drop a tailored snippet, a step‑by‑step guide, or even a small project structure example. 🚀
#
# ### CURRENT REQUEST
# The backend of my project will be built with Django.
# ---
#
# Agent > Nice! 🎉 A React frontend paired with a Django backend is a solid, full‑stack combo. Here are a few quick‑start ideas and best‑practices that might help you decide how to wire everything together. Pick the parts that resonate with you, or let me know a specific pain point and I’ll dive deeper.
#
# | What you might want to tackle | Quick‑start hints | Why it matters |
# |------------------------------|-------------------|----------------|
# | **API layer** | Use **Django REST Framework (DRF)** – serializers, viewsets, routers, and `@action` for custom endpoints. | Gives you a clean, RESTful API that your React app can `fetch` or `axios` from. |
# | **CORS** | Add `django-cors-headers` in the backend and set `CORS_ALLOWED_ORIGINS` to your dev URL (`http://localhost:5173` for Vite, or the domain you’ll host the front‑end on). | Prevents the browser’s Same‑Origin policy from blocking API calls. |
# | **Authentication** | • JWT (simple, stateless) → `djangorestframework-simplejwt` <br>• Session auth + CSRF token if you’re serving the React build from Django. | Secure login flow. JWT is great if you host React separately (e.g., Netlify, Vercel). |
# | **Deployment** | • Serve React static files via Django (collectstatic) – handy for simple apps.<br>• Or deploy React to a CDN/Vercel and point it at a separate Django API host. | Pick what fits your scaling and CI/CD strategy. |
# | **Data fetching** | Use `react-query` or SWR for caching and background refetching, or keep it simple with `fetch`/`axios`. | Reduces boilerplate and improves UX. |
# | **Environment variables** | Keep secrets on the Django side (e.g., `SECRET_KEY`, DB creds). For React, use `.env` files or a .env config in the build step. | Keeps sensitive data out of the frontend bundle. |
# | **Testing** | Unit tests in Django (`pytest-django`, `factory_boy`); component tests in React (`Jest + React Testing Library`). | Ensures each layer works in isolation and together. |
#
# ### Quick sample flow
#
# 1. **Backend**
#    ```bash
#    pip install djangorestframework djangorestframework-simplejwt django-cors-headers
#    # add to INSTALLED_APPS
#    INSTALLED_APPS = [
#        ...,
#        'rest_framework',
#        'corsheaders',
#    ]
#    # add middleware
#    MIDDLEWARE = [
#        'corsheaders.middleware.CorsMiddleware',
#        ...,
#    ]
#    # CORS settings
#    CORS_ALLOWED_ORIGINS = [
#        "http://localhost:5173",  # your Vite dev server
#    ]
#    # DRF settings
#    REST_FRAMEWORK = {
#        'DEFAULT_AUTHENTICATION_CLASSES': (
#            'rest_framework_simplejwt.authentication.JWTAuthentication',
#        ),
#    }
#    ```
#    Create a simple model, serializer, and viewset, then add a router in `urls.py`.
#
# 2. **Frontend** (React + Vite + TypeScript)
#    ```tsx
#    // src/api.ts
#    import axios from 'axios';
#
#    const api = axios.create({
#      baseURL: process.env.REACT_APP_API_URL || 'http://localhost:8000/api',
#    });
#
#    export const getTodos = () => api.get('/todos/');
#    export const createTodo = (data) => api.post('/todos/', data);
#    ```
#
# 3. **Authentication** – fetch a JWT on login, store it in memory or `localStorage`, and attach it to the `Authorization` header for subsequent calls.
#
# If you’d like a more detailed walk‑through on any of these steps (setting up DRF, configuring JWT, CORS, or wiring up the React fetch calls), just let me know! 🚀
# (LLM Generation Time: 1.6830 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > What cities am I planning to visit on my vacation?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 1.0532 seconds
# Estimated Prompt Tokens: 65
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Relevant Information Retrieved from Memory:
# User said: I want to visit Tokyo and Kyoto while I'm on my trip.
# ---
# User said: I am planning a vacation to Japan for next spring.
#
# ### CURRENT REQUEST
# What cities am I planning to visit on my vacation?
# ---
#
# Agent > You’re planning to visit **Tokyo** and **Kyoto** on your trip to Japan.
# (LLM Generation Time: 0.2518 seconds)
# ======================================================================
# Retrieval memory (documents and FAISS index) cleared.

# %% [markdown]
# ### Strategy 5: Memory-Augmented Transformers (Conceptual Simulation)
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Rich, evolving contexts over time                    | Advanced models, costlier                              |
#
# **Theory:** This is a modification to the *model architecture itself* and cannot be fully implemented at the agent level. However, we can *simulate its behavior*. The core idea is that the model has access to a special, compressed memory space (like "sticky notes") in addition to its normal context window. It learns to write key information to these memory slots and read from them when needed.
#
# **Our Simulation:** We will create a `MemoryAugmentedMemory` class. After each turn, it will use the LLM to decide if any information is important enough to be a "key memory." If so, it will create a concise summary of that fact and store it in a special list of `memory_tokens`. The final context will be a combination of a sliding window of recent chat and these important `memory_tokens`.

# %%
# --- Strategy 5: Memory-Augmented Memory (Simulation) ---
# This strategy simulates the behavior of a Memory-Augmented Transformer model.
# It maintains a short-term sliding window of recent conversation and a separate
# list of "memory tokens" which are important facts extracted from the conversation.
# An LLM call is used to decide if a piece of information is important enough
# to be converted into a persistent memory token.
class MemoryAugmentedMemory(BaseMemoryStrategy):
    def __init__(self, window_size: int = 2):
        """
        Initializes the memory-augmented system.
        
        Args:
            window_size: The number of recent turns to keep in the short-term memory.
        """
        # Use a SlidingWindowMemory instance to manage the recent conversation history.
        self.recent_memory = SlidingWindowMemory(window_size=window_size)
        # A list to store the special, persistent "sticky notes" or key facts.
        self.memory_tokens = []

    def add_message(self, user_input: str, ai_response: str):
        """
        Adds the latest turn to recent memory and then uses an LLM call to decide
        if a new, persistent memory token should be created from this interaction.
        """
        # First, add the new interaction to the short-term sliding window memory.
        self.recent_memory.add_message(user_input, ai_response)
        
        # Construct a prompt for the LLM to analyze the conversation turn and
        # determine if it contains a core fact worth remembering long-term.
        fact_extraction_prompt = (
            f"Analyze the following conversation turn. Does it contain a core fact, preference, or decision that should be remembered long-term? "
            f"Examples include user preferences ('I hate flying'), key decisions ('The budget is $1000'), or important facts ('My user ID is 12345').\n\n"
            f"Conversation Turn:\nUser: {user_input}\nAI: {ai_response}\n\n"
            f"If it contains such a fact, state the fact concisely in one sentence. Otherwise, respond with 'No important fact.'"
        )
        
        # Call the LLM to perform the fact extraction.
        extracted_fact = generate_text("You are a fact-extraction expert.", fact_extraction_prompt)
        
        # Check if the LLM's response indicates that an important fact was found.
        if "no important fact" not in extracted_fact.lower():
            # If a fact was found, print a debug message and add it to our list of memory tokens.
            print(f"--- [Memory Augmentation: New memory token created: '{extracted_fact}'] ---")
            self.memory_tokens.append(extracted_fact)

    def get_context(self, query: str) -> str:
        """
        Constructs the context by combining the short-term recent conversation
        with the list of all long-term, persistent memory tokens.
        """
        # Get the context from the short-term sliding window.
        recent_context = self.recent_memory.get_context(query)
        # Format the list of memory tokens into a readable string.
        memory_token_context = "\n".join([f"- {token}" for token in self.memory_tokens])
        
        # Return the combined context, clearly separating the long-term facts from the recent chat.
        return f"### Key Memory Tokens (Long-Term Facts):\n{memory_token_context}\n\n### Recent Conversation:\n{recent_context}"

    def clear(self):
        """Resets both the short-term memory and the list of memory tokens."""
        self.recent_memory.clear()
        self.memory_tokens = []
        print("Memory-Augmented memory cleared.")

# %% [markdown]
# #### Demonstration of Memory-Augmented Memory
#
# **What to watch for:** We'll mention a critical, long-term preference in the first turn. The agent should identify this as a "key memory" and create a memory token. After several more turns push the original message out of the recent chat window, the agent should still be able to recall the preference by reading its memory token.

# %%
# Initialize the MemoryAugmentedMemory with a window size of 2.
# This means the short-term memory will only hold the last two turns.
mem_aug_memory = MemoryAugmentedMemory(window_size=2)
# Create an AIAgent and inject the memory-augmented strategy.
agent = AIAgent(memory_strategy=mem_aug_memory)

# --- Start the conversation ---
# First turn: The user provides a critical, long-term piece of information.
# The agent's fact-extraction mechanism should identify this as important and create a memory token.
agent.chat("Please remember this for all future interactions: I am severely allergic to peanuts.")

# Second turn: A standard conversational turn.
agent.chat("Okay, let's talk about recipes. What's a good idea for dinner tonight?")

# Third turn: Another conversational turn. This will push the first turn (the allergy warning)
# out of the short-term sliding window memory.
agent.chat("That sounds good. What about a dessert option?")

# --- Test the memory augmentation ---
# Now, the critical test. The original allergy warning is no longer in the recent chat context.
# The agent's only way to know about the allergy is by accessing its long-term "memory tokens".
agent.chat("Could you suggest a Thai green curry recipe? Please ensure it's safe for me.")
# A successful agent will use the persistent memory token to check for safety and likely warn
# about peanuts, which are common in Thai cuisine.

# Clean up the memory for the next demonstration.
mem_aug_memory.clear()
# Out:
# Agent initialized with MemoryAugmentedMemory.
#
# ========================= NEW INTERACTION =========================
# User > Please remember this for all future interactions: I am severely allergic to peanuts.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 45
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Key Memory Tokens (Long-Term Facts):
#
#
# ### Recent Conversation:
#
#
# ### CURRENT REQUEST
# Please remember this for all future interactions: I am severely allergic to peanuts.
# ---
# --- [Memory Augmentation: New memory token created: 'The user is severely allergic to peanuts.'] ---
#
# Agent > I’ve noted that you’re severely allergic to peanuts. I’ll keep this in mind for all future interactions.
# (LLM Generation Time: 0.6362 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Okay, let's talk about recipes. What's a good idea for dinner tonight?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 96
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Key Memory Tokens (Long-Term Facts):
# - The user is severely allergic to peanuts.
#
# ### Recent Conversation:
# User: Please remember this for all future interactions: I am severely allergic to peanuts.
# Assistant: I’ve noted that you’re severely allergic to peanuts. I’ll keep this in mind for all future interactions.
#
# ### CURRENT REQUEST
# Okay, let's talk about recipes. What's a good idea for dinner tonight?
# ---
#
# Agent > **Dinner Idea:**
# **Herb‑Crusted Pork Tenderloin with Roasted Sweet Potatoes & Green Beans**
# *(Peanut‑free and easy to make in under 45 minutes)*
#
# ---
#
# ### Why it’s a great choice
#
# - **Balanced flavors**: The savory pork is complemented by sweet, caramelized potatoes and crisp‑fresh green beans.
# - **Quick & minimal cleanup** – one sheet pan does the job!
# - **Customizable** – swap pork for chicken or turkey, or make it vegetarian with a hearty portobello steak.
# - **Peanut‑free** – we’ve double‑checked that none of the ingredients contain peanuts or peanut derivatives.
#
# ---
#
# ## Ingredients
#
# | Item | Qty | Notes |
# |------|-----|-------|
# | Pork tenderloin (or chicken thighs) | 1‑1.5 lb | Trim fat and slice into 1‑in thick medallions (or use one whole tenderloin). |
# | Olive oil | 2 Tbsp | For coating and roasting. |
# | Fresh rosemary | 2 Tbsp, chopped | Or 1 tsp dried. |
# | Fresh thyme | 2 Tbsp, chopped | Or 1 tsp dried. |
# | Garlic | 3 cloves, minced | |
# | Lemon zest | 1 Tbsp | Adds brightness. |
# | Salt & pepper | to taste | |
# | Sweet potatoes | 2 large, cubed | Cut into 1‑inch pieces. |
# | Green beans | 1 lb, trimmed | |
# | Optional: red bell pepper | 1, sliced | For extra color. |
#
# > **Peanut‑free confirmation**: All items are free from peanuts, peanut butter, or peanut oil. Check the labels if you’re using packaged spices or pre‑mixed seasoning blends.
#
# ---
#
# ## Instructions
#
# 1. **Preheat** your oven to 425 °F (220 °C). Line a large baking sheet with parchment or a silicone mat.
#
# 2. **Prepare the herb rub:**
#    In a small bowl, mix the chopped rosemary, thyme, minced garlic, lemon zest, olive oil, salt, and pepper. The olive oil helps the herbs stick to the pork.
#
# 3. **Season the pork:**
#    Pat the pork medallions dry with paper towels. Rub the herb mixture all over each piece. If you’re using a whole tenderloin, coat it evenly.
#
# 4. **Arrange veggies:**
#    Spread the sweet potato cubes, green beans, and optional bell pepper slices on the same sheet (or a second sheet if needed). Drizzle with a little olive oil and season with salt & pepper. Toss to coat.
#
# 5. **Cook:**
#    Place the sheet(s) in the oven. Roast for 18–22 minutes, turning the veggies halfway through. The pork should reach an internal temperature of 145 °F (63 °C) with a 3‑minute rest, or use a meat thermometer for accuracy.
#
# 6. **Rest & serve:**
#    Let the pork rest for 5 minutes before slicing. Plate the pork with a generous portion of roasted veggies. Drizzle any pan juices over the top for extra flavor.
#
# ---
#
# ## Quick Variations
#
# | Variation | Swap / Add | Result |
# |-----------|------------|--------|
# | **Vegetarian** | Replace pork with a 12‑oz portobello mushroom cap, sliced | Hearty, umami‑rich |
# | **Spicy** | Add ¼ tsp crushed red pepper flakes to the rub | A kick of heat |
# | **Gluten‑free** | Ensure any packaged spices are gluten‑free | Safe for celiac or gluten‑sensitive |
# | **Low‑carb** | Omit sweet potatoes; add cauliflower florets | Keeps carbs down |
#
# ---
#
# ### Final Tip
#
# If you’re curious about the nutrition or want a side of quinoa or a light salad, let me know! This recipe is designed to keep the cooking time short while staying completely peanut‑free. Enjoy your dinner!
# (LLM Generation Time: 1.5984 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > That sounds good. What about a dessert option?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 971
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Key Memory Tokens (Long-Term Facts):
# - The user is severely allergic to peanuts.
#
# ### Recent Conversation:
# User: Please remember this for all future interactions: I am severely allergic to peanuts.
# Assistant: I’ve noted that you’re severely allergic to peanuts. I’ll keep this in mind for all future interactions.
# User: Okay, let's talk about recipes. What's a good idea for dinner tonight?
# Assistant: **Dinner Idea:**
# **Herb‑Crusted Pork Tenderloin with Roasted Sweet Potatoes & Green Beans**
# *(Peanut‑free and easy to make in under 45 minutes)*
#
# ---
#
# ### Why it’s a great choice
#
# - **Balanced flavors**: The savory pork is complemented by sweet, caramelized potatoes and crisp‑fresh green beans.
# - **Quick & minimal cleanup** – one sheet pan does the job!
# - **Customizable** – swap pork for chicken or turkey, or make it vegetarian with a hearty portobello steak.
# - **Peanut‑free** – we’ve double‑checked that none of the ingredients contain peanuts or peanut derivatives.
#
# ---
#
# ## Ingredients
#
# | Item | Qty | Notes |
# |------|-----|-------|
# | Pork tenderloin (or chicken thighs) | 1‑1.5 lb | Trim fat and slice into 1‑in thick medallions (or use one whole tenderloin). |
# | Olive oil | 2 Tbsp | For coating and roasting. |
# | Fresh rosemary | 2 Tbsp, chopped | Or 1 tsp dried. |
# | Fresh thyme | 2 Tbsp, chopped | Or 1 tsp dried. |
# | Garlic | 3 cloves, minced | |
# | Lemon zest | 1 Tbsp | Adds brightness. |
# | Salt & pepper | to taste | |
# | Sweet potatoes | 2 large, cubed | Cut into 1‑inch pieces. |
# | Green beans | 1 lb, trimmed | |
# | Optional: red bell pepper | 1, sliced | For extra color. |
#
# > **Peanut‑free confirmation**: All items are free from peanuts, peanut butter, or peanut oil. Check the labels if you’re using packaged spices or pre‑mixed seasoning blends.
#
# ---
#
# ## Instructions
#
# 1. **Preheat** your oven to 425 °F (220 °C). Line a large baking sheet with parchment or a silicone mat.
#
# 2. **Prepare the herb rub:**
#    In a small bowl, mix the chopped rosemary, thyme, minced garlic, lemon zest, olive oil, salt, and pepper. The olive oil helps the herbs stick to the pork.
#
# 3. **Season the pork:**
#    Pat the pork medallions dry with paper towels. Rub the herb mixture all over each piece. If you’re using a whole tenderloin, coat it evenly.
#
# 4. **Arrange veggies:**
#    Spread the sweet potato cubes, green beans, and optional bell pepper slices on the same sheet (or a second sheet if needed). Drizzle with a little olive oil and season with salt & pepper. Toss to coat.
#
# 5. **Cook:**
#    Place the sheet(s) in the oven. Roast for 18–22 minutes, turning the veggies halfway through. The pork should reach an internal temperature of 145 °F (63 °C) with a 3‑minute rest, or use a meat thermometer for accuracy.
#
# 6. **Rest & serve:**
#    Let the pork rest for 5 minutes before slicing. Plate the pork with a generous portion of roasted veggies. Drizzle any pan juices over the top for extra flavor.
#
# ---
#
# ## Quick Variations
#
# | Variation | Swap / Add | Result |
# |-----------|------------|--------|
# | **Vegetarian** | Replace pork with a 12‑oz portobello mushroom cap, sliced | Hearty, umami‑rich |
# | **Spicy** | Add ¼ tsp crushed red pepper flakes to the rub | A kick of heat |
# | **Gluten‑free** | Ensure any packaged spices are gluten‑free | Safe for celiac or gluten‑sensitive |
# | **Low‑carb** | Omit sweet potatoes; add cauliflower florets | Keeps carbs down |
#
# ---
#
# ### Final Tip
#
# If you’re curious about the nutrition or want a side of quinoa or a light salad, let me know! This recipe is designed to keep the cooking time short while staying completely peanut‑free. Enjoy your dinner!
#
# ### CURRENT REQUEST
# That sounds good. What about a dessert option?
# ---
#
# Agent > ### Peanut‑Free Dessert Idea
# **Chocolate‑Avocado Mousse with a Crunchy Berry Topping**
# *(Creamy, chocolatey, and completely free of peanuts – perfect for a quick, indulgent finish to your dinner)*
#
# ---
#
# #### Why it fits
#
# - **Zero peanuts** – all ingredients are naturally peanut‑free (just double‑check any boxed chocolate or spices you might use).
# - **Very quick** – 10‑minute prep, 30‑minute chill.
# - **Healthy twist** – avocado provides healthy fats; berries add antioxidants.
# - **Kid‑friendly & adult‑approved** – rich chocolate flavor without the need for powdered sugar or heavy creams.
#
# ---
#
# ### Ingredients
#
# | Item | Qty | Notes |
# |------|-----|-------|
# | Ripe avocado (medium) | 2 (about 400 g) | Choose soft, buttery ones. |
# | Dark chocolate (70 % cocoa or higher) | 100 g | Finely chopped or chips – look for “no peanut” on the label. |
# | Unsweetened cocoa powder | 2 Tbsp | + extra for dusting. |
# | Maple syrup or honey | 3 Tbsp | Sweetener of choice – adjust to taste. |
# | Vanilla extract | 1 tsp | Adds depth. |
# | Pinch of sea salt | 1/4 tsp | Balances sweetness. |
# | Fresh mixed berries (strawberries, blueberries, raspberries) | 1 cup | For topping. |
# | Optional crunch: toasted coconut flakes or chopped macadamia nuts | 2 Tbsp | Be sure they’re peanut‑free. |
#
# > **Peanut‑free check**: Verify that the chocolate and any pre‑mixed powders do not list “peanut” or “peanut oil” on their ingredient list. If using a commercial “chocolate mousse” base, look for a “peanut‑free” label.
#
# ---
#
# ### Instructions
#
# 1. **Melt the chocolate**
#    - Place the chopped chocolate in a heat‑proof bowl over a pot of simmering water (double boiler). Stir until smooth. Remove from heat.
#
# 2. **Blend the avocado**
#    - In a blender or high‑speed food processor, combine the avocado flesh, melted chocolate, cocoa powder, maple syrup, vanilla extract, and sea salt. Blend until silky and uniform (about 30‑60 seconds). Taste and adjust sweetness if needed.
#
# 3. **Refrigerate**
#    - Spoon the mousse into individual serving glasses or a shallow bowl. Cover and chill in the fridge for at least 30 minutes (or up to 2 hrs for a firmer texture).
#
# 4. **Add the topping**
#    - Just before serving, scatter the fresh berries over the mousse. If using, sprinkle a pinch of toasted coconut flakes or chopped macadamia nuts for extra crunch.
#
# 5. **Serve**
#    - A light dusting of additional cocoa powder or a few extra berries makes a pretty finishing touch.
#
# ---
#
# ### Variations & Pairings
#
# | Variation | Swap / Add | Result |
# |-----------|-----------|--------|
# | **Citrus Kick** | Add 1 Tbsp fresh orange zest to the blend | Bright, slightly tart contrast to chocolate. |
# | **Minty Twist** | Mix in 1/2 tsp fresh mint or 1 Tbsp peppermint extract | Refreshing after a savory dinner. |
# | **Nut‑Free Crunch** | Use roasted pumpkin seeds instead of coconut flakes | Adds a satisfying bite while remaining allergen‑safe. |
# | **Low‑Sugar** | Replace maple syrup with stevia or a sugar‑free sweetener | Still creamy, but lighter on carbs. |
# | **Chocolate‑Berry Fusion** | Fold in a handful of chocolate‑covered strawberries (check for nut allergies) | Sweet and visually appealing. |
#
# ---
#
# ### Quick Nutrition Snapshot (per serving, 1/4 of the recipe)
#
# | Nutrient | Approx. Value |
# |----------|---------------|
# | Calories | 350–380 kcal |
# | Protein | 4 g |
# | Fat | 27 g (mostly healthy monounsaturated & polyunsaturated from avocado & chocolate) |
# | Carbs | 34 g |
# | Fiber | 7 g |
# | Sugar | 11 g (from maple syrup & berries) |
#
# *(Values vary with ingredient brands; adjust based on your own measurements.)*
#
# ---
#
# ### Final Tips
#
# - **Peanut‑free safety**: If you’re dining out or buying pre‑made items (e.g., chocolate chips), read labels carefully for “peanuts” or “peanut oil.”
# - **Serve with coffee or tea**: A small cup of espresso or herbal tea complements the dessert wonderfully.
# - **Make it ahead**: The mousse can be prepared up to 24 hrs in advance and kept refrigerated. Just give it a gentle stir before serving.
#
# Enjoy your chocolate‑avocado mousse—rich, silky, and completely safe for your peanut allergy! If you’d like another dessert idea (e.g., a fruit tart, a no‑bake cheesecake, or something else), just let me know.
# (LLM Generation Time: 2.0138 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Could you suggest a Thai green curry recipe? Please ensure it's safe for me.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 2062
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Key Memory Tokens (Long-Term Facts):
# - The user is severely allergic to peanuts.
#
# ### Recent Conversation:
# User: Okay, let's talk about recipes. What's a good idea for dinner tonight?
# Assistant: **Dinner Idea:**
# **Herb‑Crusted Pork Tenderloin with Roasted Sweet Potatoes & Green Beans**
# *(Peanut‑free and easy to make in under 45 minutes)*
#
# ---
#
# ### Why it’s a great choice
#
# - **Balanced flavors**: The savory pork is complemented by sweet, caramelized potatoes and crisp‑fresh green beans.
# - **Quick & minimal cleanup** – one sheet pan does the job!
# - **Customizable** – swap pork for chicken or turkey, or make it vegetarian with a hearty portobello steak.
# - **Peanut‑free** – we’ve double‑checked that none of the ingredients contain peanuts or peanut derivatives.
#
# ---
#
# ## Ingredients
#
# | Item | Qty | Notes |
# |------|-----|-------|
# | Pork tenderloin (or chicken thighs) | 1‑1.5 lb | Trim fat and slice into 1‑in thick medallions (or use one whole tenderloin). |
# | Olive oil | 2 Tbsp | For coating and roasting. |
# | Fresh rosemary | 2 Tbsp, chopped | Or 1 tsp dried. |
# | Fresh thyme | 2 Tbsp, chopped | Or 1 tsp dried. |
# | Garlic | 3 cloves, minced | |
# | Lemon zest | 1 Tbsp | Adds brightness. |
# | Salt & pepper | to taste | |
# | Sweet potatoes | 2 large, cubed | Cut into 1‑inch pieces. |
# | Green beans | 1 lb, trimmed | |
# | Optional: red bell pepper | 1, sliced | For extra color. |
#
# > **Peanut‑free confirmation**: All items are free from peanuts, peanut butter, or peanut oil. Check the labels if you’re using packaged spices or pre‑mixed seasoning blends.
#
# ---
#
# ## Instructions
#
# 1. **Preheat** your oven to 425 °F (220 °C). Line a large baking sheet with parchment or a silicone mat.
#
# 2. **Prepare the herb rub:**
#    In a small bowl, mix the chopped rosemary, thyme, minced garlic, lemon zest, olive oil, salt, and pepper. The olive oil helps the herbs stick to the pork.
#
# 3. **Season the pork:**
#    Pat the pork medallions dry with paper towels. Rub the herb mixture all over each piece. If you’re using a whole tenderloin, coat it evenly.
#
# 4. **Arrange veggies:**
#    Spread the sweet potato cubes, green beans, and optional bell pepper slices on the same sheet (or a second sheet if needed). Drizzle with a little olive oil and season with salt & pepper. Toss to coat.
#
# 5. **Cook:**
#    Place the sheet(s) in the oven. Roast for 18–22 minutes, turning the veggies halfway through. The pork should reach an internal temperature of 145 °F (63 °C) with a 3‑minute rest, or use a meat thermometer for accuracy.
#
# 6. **Rest & serve:**
#    Let the pork rest for 5 minutes before slicing. Plate the pork with a generous portion of roasted veggies. Drizzle any pan juices over the top for extra flavor.
#
# ---
#
# ## Quick Variations
#
# | Variation | Swap / Add | Result |
# |-----------|------------|--------|
# | **Vegetarian** | Replace pork with a 12‑oz portobello mushroom cap, sliced | Hearty, umami‑rich |
# | **Spicy** | Add ¼ tsp crushed red pepper flakes to the rub | A kick of heat |
# | **Gluten‑free** | Ensure any packaged spices are gluten‑free | Safe for celiac or gluten‑sensitive |
# | **Low‑carb** | Omit sweet potatoes; add cauliflower florets | Keeps carbs down |
#
# ---
#
# ### Final Tip
#
# If you’re curious about the nutrition or want a side of quinoa or a light salad, let me know! This recipe is designed to keep the cooking time short while staying completely peanut‑free. Enjoy your dinner!
# User: That sounds good. What about a dessert option?
# Assistant: ### Peanut‑Free Dessert Idea
# **Chocolate‑Avocado Mousse with a Crunchy Berry Topping**
# *(Creamy, chocolatey, and completely free of peanuts – perfect for a quick, indulgent finish to your dinner)*
#
# ---
#
# #### Why it fits
#
# - **Zero peanuts** – all ingredients are naturally peanut‑free (just double‑check any boxed chocolate or spices you might use).
# - **Very quick** – 10‑minute prep, 30‑minute chill.
# - **Healthy twist** – avocado provides healthy fats; berries add antioxidants.
# - **Kid‑friendly & adult‑approved** – rich chocolate flavor without the need for powdered sugar or heavy creams.
#
# ---
#
# ### Ingredients
#
# | Item | Qty | Notes |
# |------|-----|-------|
# | Ripe avocado (medium) | 2 (about 400 g) | Choose soft, buttery ones. |
# | Dark chocolate (70 % cocoa or higher) | 100 g | Finely chopped or chips – look for “no peanut” on the label. |
# | Unsweetened cocoa powder | 2 Tbsp | + extra for dusting. |
# | Maple syrup or honey | 3 Tbsp | Sweetener of choice – adjust to taste. |
# | Vanilla extract | 1 tsp | Adds depth. |
# | Pinch of sea salt | 1/4 tsp | Balances sweetness. |
# | Fresh mixed berries (strawberries, blueberries, raspberries) | 1 cup | For topping. |
# | Optional crunch: toasted coconut flakes or chopped macadamia nuts | 2 Tbsp | Be sure they’re peanut‑free. |
#
# > **Peanut‑free check**: Verify that the chocolate and any pre‑mixed powders do not list “peanut” or “peanut oil” on their ingredient list. If using a commercial “chocolate mousse” base, look for a “peanut‑free” label.
#
# ---
#
# ### Instructions
#
# 1. **Melt the chocolate**
#    - Place the chopped chocolate in a heat‑proof bowl over a pot of simmering water (double boiler). Stir until smooth. Remove from heat.
#
# 2. **Blend the avocado**
#    - In a blender or high‑speed food processor, combine the avocado flesh, melted chocolate, cocoa powder, maple syrup, vanilla extract, and sea salt. Blend until silky and uniform (about 30‑60 seconds). Taste and adjust sweetness if needed.
#
# 3. **Refrigerate**
#    - Spoon the mousse into individual serving glasses or a shallow bowl. Cover and chill in the fridge for at least 30 minutes (or up to 2 hrs for a firmer texture).
#
# 4. **Add the topping**
#    - Just before serving, scatter the fresh berries over the mousse. If using, sprinkle a pinch of toasted coconut flakes or chopped macadamia nuts for extra crunch.
#
# 5. **Serve**
#    - A light dusting of additional cocoa powder or a few extra berries makes a pretty finishing touch.
#
# ---
#
# ### Variations & Pairings
#
# | Variation | Swap / Add | Result |
# |-----------|-----------|--------|
# | **Citrus Kick** | Add 1 Tbsp fresh orange zest to the blend | Bright, slightly tart contrast to chocolate. |
# | **Minty Twist** | Mix in 1/2 tsp fresh mint or 1 Tbsp peppermint extract | Refreshing after a savory dinner. |
# | **Nut‑Free Crunch** | Use roasted pumpkin seeds instead of coconut flakes | Adds a satisfying bite while remaining allergen‑safe. |
# | **Low‑Sugar** | Replace maple syrup with stevia or a sugar‑free sweetener | Still creamy, but lighter on carbs. |
# | **Chocolate‑Berry Fusion** | Fold in a handful of chocolate‑covered strawberries (check for nut allergies) | Sweet and visually appealing. |
#
# ---
#
# ### Quick Nutrition Snapshot (per serving, 1/4 of the recipe)
#
# | Nutrient | Approx. Value |
# |----------|---------------|
# | Calories | 350–380 kcal |
# | Protein | 4 g |
# | Fat | 27 g (mostly healthy monounsaturated & polyunsaturated from avocado & chocolate) |
# | Carbs | 34 g |
# | Fiber | 7 g |
# | Sugar | 11 g (from maple syrup & berries) |
#
# *(Values vary with ingredient brands; adjust based on your own measurements.)*
#
# ---
#
# ### Final Tips
#
# - **Peanut‑free safety**: If you’re dining out or buying pre‑made items (e.g., chocolate chips), read labels carefully for “peanuts” or “peanut oil.”
# - **Serve with coffee or tea**: A small cup of espresso or herbal tea complements the dessert wonderfully.
# - **Make it ahead**: The mousse can be prepared up to 24 hrs in advance and kept refrigerated. Just give it a gentle stir before serving.
#
# Enjoy your chocolate‑avocado mousse—rich, silky, and completely safe for your peanut allergy! If you’d like another dessert idea (e.g., a fruit tart, a no‑bake cheesecake, or something else), just let me know.
#
# ### CURRENT REQUEST
# Could you suggest a Thai green curry recipe? Please ensure it's safe for me.
# ---
#
# Agent > **Safe & Savory Thai Green Curry**
# *(A peanut‑free, easy‑to‑make curry that keeps all the authentic flavors while respecting your allergy.)*
#
# ---
#
# ### Why this one?
#
# - **All‑natural, peanut‑free base** – Coconut milk + a store‑bought or homemade green‑curry paste (no peanuts/peanut oil).
# - **Customizable protein & veggies** – Chicken, shrimp, tofu, or just a rainbow of vegetables.
# - **Quick** – 30‑minute prep + 15‑minute simmer.
# - **Pairings** – Jasmine rice, rice noodles, or cauliflower rice for a low‑carb option.
#
# ---
#
# ## Ingredients
#
# | Item | Qty | Notes |
# |------|-----|-------|
# | **Protein** | 1 lb (450 g) | Chicken breast, shrimp, or firm tofu (cut into cubes). |
# | **Coconut milk** | 1 can (400 mL) | Full‑fat for creaminess; use a brand that lists “soy‑free” if needed. |
# | **Thai green curry paste** | 3 Tbsp | Check label for “peanut” or “peanut oil”.  (You can also make a simple paste: 2 green chilies, 1/2 tsp lemongrass, 1 garlic clove, 1/2 tsp galangal, 1/2 tsp coriander seeds, pinch of cumin, 1/2 tsp shrimp paste – blend in a mortar or blender.) |
# | **Vegetables** | 2 cups | Bell pepper (sliced), zucchini (cubed), snow peas, eggplant (cubed), bamboo shoots (optional). |
# | **Fresh herbs** | 2 Tbsp chopped Thai basil | (or sweet basil if unavailable) |
# | **Lime juice** | 1 Tbsp | Freshly squeezed. |
# | **Fish sauce** | 2 Tbsp | Use a brand that lists no peanuts. |
# | **Brown sugar** | 1 Tbsp | Adjust to taste. |
# | **Vegetable oil** | 2 Tbsp | Coconut oil or canola; make sure it’s peanut‑free. |
# | **Optional** | 1 Tbsp lime zest | For extra citrus brightness. |
# | **Optional** | 1 Tbsp fresh ginger, grated | Adds warmth. |
#
# > **Peanut‑free check**: All bulk ingredients are naturally peanut‑free. For pre‑packaged items (curry paste, coconut milk, fish sauce), scan the ingredient list for “peanut”, “peanut oil”, or “peanut flour.”
#
# ---
#
# ## Quick Instructions
#
# 1. **Prep**
#    - Slice protein into bite‑size pieces.
#    - Dice veggies into uniform pieces so they cook evenly.
#
# 2. **Cook the protein**
#    - Heat 1 Tbsp oil in a large skillet or wok over medium‑high heat.
#    - Add protein, season with a pinch of salt, and stir‑fry until browned (shrimp: ~2 min; chicken: 4–5 min; tofu: 3 min). Remove to a plate and set aside.
#
# 3. **Sauté aromatics**
#    - In the same pan, add the remaining oil.
#    - Toss in the green curry paste, fresh ginger (if using), and 1 Tbsp water. Fry for 30 sec until fragrant.
#
# 4. **Add liquid**
#    - Pour in the coconut milk and stir to dissolve the paste.
#    - Add fish sauce, brown sugar, and lime zest (if using). Bring to a gentle simmer.
#
# 5. **Vegetables**
#    - Add the firmer veggies first (zucchini, eggplant, bamboo shoots) for 2–3 min, then the softer ones (bell pepper, snow peas).
#    - Return the cooked protein to the pan.
#
# 6. **Simmer**
#    - Let everything simmer for 8–10 min until veggies are tender and the curry has thickened slightly.
#    - Stir in fresh lime juice and basil just before removing from heat.
#
# 7. **Taste & adjust**
#    - If it needs more sweetness, add a dash more brown sugar; for saltiness, a splash more fish sauce; for heat, a few extra chopped chilies.
#
# 8. **Serve**
#    - Spoon the curry over steamed jasmine rice, rice noodles, or cauliflower rice.
#    - Garnish with extra basil, lime wedges, or a sprinkle of toasted coconut flakes for texture.
#
# ---
#
# ## Variations & Safety Tips
#
# | Variation | Swap / Add | Result | Peanut‑free Note |
# |-----------|-----------|--------|-------------------|
# | **Vegetarian** | Replace protein with tofu or chickpeas | Still creamy & filling | Tofu often packaged in soy‑free lines; check for “no peanuts.” |
# | **Low‑fat** | Use light coconut milk or half‑and‑half | Lighter texture | Light coconut milk sometimes contains additives—check for peanuts. |
# | **Spicy** | Add extra sliced green chilies or a dash of sriracha | Higher heat | Sriracha labels often include sesame oil; read for peanuts. |
# | **Nut‑free crunch** | Top with toasted pumpkin seeds | Adds bite | Seeds are safe for peanut allergy. |
# | **Gluten‑free** | Verify fish sauce is gluten‑free (some brands contain wheat) | Safe for celiacs | Also double‑check curry paste for wheat. |
#
# ### Ensuring Peanut Safety
# 1. **Read the labels**: Look for “peanut,” “peanut oil,” or “peanut flour.”
# 2. **Cross‑contamination**: If you’re using a shared kitchen or a store that also stocks peanut products, ask the staff whether the cooking oil and utensils might have been used for peanuts.
# 3. **Homemade paste**: Making your own curry paste from fresh chilies, lemongrass, garlic, and spices guarantees no hidden peanuts.
# 4. **Storage**: Keep all pantry items in sealed containers to avoid airborne peanut particles if you live with a peanut allergy.
#
# ---
#
# ## Serving Suggestions
#
# - **Rice**: Classic jasmine or basmati; for a low‑carb twist, use cauliflower rice or zucchini noodles.
# - **Accompaniments**: Lime wedges, extra fresh basil, chopped cilantro, sliced chili for those who like heat.
# - **Beverage**: A cold jasmine tea or a light white wine (e.g., Riesling) pairs well.
#
# Enjoy this fragrant, peanut‑free Thai green curry that’s perfect for a quick dinner or a family gathering! If you’d like a side salad, a simple cucumber‑lime slaw would balance the richness nicely. Let me know if you need a recipe for that too.
# (LLM Generation Time: 2.4392 seconds)
# ======================================================================
# Sliding window memory cleared.
# Memory-Augmented memory cleared.

# %% [markdown]
# ### Strategy 6: Hierarchical Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Multi-task, complex agents with different info types | Sophisticated management logic                         |
#
# **Theory:** This is a composite strategy that mimics how human memory works at different levels. It combines multiple, simpler memory strategies into a hierarchy. A common setup is:
# - **Level 1 (Working Memory):** A `SlidingWindowMemory` for fast, immediate context.
# - **Level 2 (Long-Term Memory):** A `RetrievalMemory` for storing important, durable facts.
#
# The key is the logic that **promotes** information from L1 to L2. Our implementation will use a heuristic: if a conversation turn seems particularly important (e.g., contains a keyword like "preference" or "rule"), it gets added to both the working and long-term stores.

# %%
# --- Strategy 6: Hierarchical Memory ---
# This strategy combines multiple memory types to create a more sophisticated,
# layered system, mimicking human memory's division into short-term (working)
# and long-term storage.
class HierarchicalMemory(BaseMemoryStrategy):
    def __init__(self, window_size: int = 2, k: int = 2, embedding_dim: int = 768):
        """
        Initializes the hierarchical memory system.
        
        Args:
            window_size: The size of the short-term working memory (in turns).
            k: The number of documents to retrieve from long-term memory.
            embedding_dim: The dimension of the embedding vectors for long-term memory.
        """
        print("Initializing Hierarchical Memory...")
        # Level 1: Fast, short-term working memory using a sliding window.
        self.working_memory = SlidingWindowMemory(window_size=window_size)
        # Level 2: Slower, durable long-term memory using a retrieval system.
        self.long_term_memory = RetrievalMemory(k=k, embedding_dim=embedding_dim)
        # A simple heuristic: keywords that trigger promotion from working to long-term memory.
        self.promotion_keywords = ["remember", "rule", "preference", "always", "never", "allergic"]

    def add_message(self, user_input: str, ai_response: str):
        """
        Adds a message to working memory and conditionally promotes it to long-term
        memory based on its content.
        """
        # All interactions are added to the fast, short-term working memory.
        self.working_memory.add_message(user_input, ai_response)
        
        # Promotion Logic: Check if the user's input contains a keyword that
        # suggests the information is important and should be stored long-term.
        if any(keyword in user_input.lower() for keyword in self.promotion_keywords):
            print(f"--- [Hierarchical Memory: Promoting message to long-term storage.] ---")
            # If a keyword is found, also add the interaction to the long-term retrieval memory.
            self.long_term_memory.add_message(user_input, ai_response)

    def get_context(self, query: str) -> str:
        """
        Constructs a rich context by combining relevant information from both
        the long-term and short-term memory layers.
        """
        # Retrieve the most recent conversation from the working memory.
        working_context = self.working_memory.get_context(query)
        # Retrieve semantically relevant facts from the long-term memory based on the current query.
        long_term_context = self.long_term_memory.get_context(query)
        
        # Combine both contexts, clearly labeling their sources for the LLM.
        return f"### Retrieved Long-Term Memories:\n{long_term_context}\n\n### Recent Conversation (Working Memory):\n{working_context}"

    def clear(self):
        """Resets both the working and long-term memory stores."""
        self.working_memory.clear()
        self.long_term_memory.clear()
        print("Hierarchical memory cleared.")

# %% [markdown]
# #### Demonstration of Hierarchical Memory
#
# **What to watch for:** We will state a preference using the keyword "remember". This will trigger the message to be saved in the long-term `RetrievalMemory`. After a few turns push it out of the short-term `SlidingWindowMemory`, we'll ask a related question. The agent should successfully answer by retrieving from its long-term store.

# %%
# Initialize the HierarchicalMemory. It combines a short-term sliding window
# and a long-term retrieval system.
hierarchical_memory = HierarchicalMemory()
# Create an AIAgent and inject the hierarchical memory strategy.
agent = AIAgent(memory_strategy=hierarchical_memory)

# --- Start the conversation ---
# First turn: The user provides an important piece of information with a keyword ("remember").
# This should trigger the promotion logic, saving this message to both short-term and long-term memory.
agent.chat("Please remember my User ID is AX-7890.")
# Second turn: A casual conversation topic. This is added to short-term memory.
agent.chat("Let's chat about the weather. It's very sunny today.")
# Third turn: Another casual topic. This pushes the first message (User ID) out of the
# short-term sliding window memory.
agent.chat("I'm planning to go for a walk later.")

# --- Test the hierarchical retrieval ---
# The User ID is now out of the working memory's window.
# The agent must now rely on its long-term, retrieval-based memory.
agent.chat("I need to log into my account, can you remind me of my ID?")
# A successful agent will retrieve 'AX-7890' from its long-term memory because the initial
# message was promoted due to the keyword "remember".

# Clean up the memory for the next demonstration.
hierarchical_memory.clear()
# Out:
# Initializing Hierarchical Memory...
# Agent initialized with HierarchicalMemory.
#
# ========================= NEW INTERACTION =========================
# User > Please remember my User ID is AX-7890.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 47
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Retrieved Long-Term Memories:
# No information in memory yet.
#
# ### Recent Conversation (Working Memory):
#
#
# ### CURRENT REQUEST
# Please remember my User ID is AX-7890.
# ---
# --- [Hierarchical Memory: Promoting message to long-term storage.] ---
#
# Agent > Got it! I've stored your User ID as **AX-7890**. If you need anything else, just let me know!
# (LLM Generation Time: 0.4018 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Let's chat about the weather. It's very sunny today.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 1.0908 seconds
# Estimated Prompt Tokens: 138
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Retrieved Long-Term Memories:
# ### Relevant Information Retrieved from Memory:
# User said: Please remember my User ID is AX-7890.
# ---
# AI responded: Got it! I've stored your User ID as **AX-7890**. If you need anything else, just let me know!
#
# ### Recent Conversation (Working Memory):
# User: Please remember my User ID is AX-7890.
# Assistant: Got it! I've stored your User ID as **AX-7890**. If you need anything else, just let me know!
#
# ### CURRENT REQUEST
# Let's chat about the weather. It's very sunny today.
# ---
#
# Agent > Sounds great! 🌞 A bright, sunny day is always a good excuse to talk about the weather. Do you happen to know your current location or the city you’re in? That way I can give you a more tailored update—whether it’s the typical high and low temps, humidity, or what the forecast looks like for the next few days. If you prefer, I can keep it more general and chat about sunny weather in general: why it feels so uplifting, how it affects plants, or even fun sunny‑day activities. Let me know what you’re in the mood for!
# (LLM Generation Time: 0.3747 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > I'm planning to go for a walk later.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.6980 seconds
# Estimated Prompt Tokens: 272
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Retrieved Long-Term Memories:
# ### Relevant Information Retrieved from Memory:
# User said: Please remember my User ID is AX-7890.
# ---
# AI responded: Got it! I've stored your User ID as **AX-7890**. If you need anything else, just let me know!
#
# ### Recent Conversation (Working Memory):
# User: Please remember my User ID is AX-7890.
# Assistant: Got it! I've stored your User ID as **AX-7890**. If you need anything else, just let me know!
# User: Let's chat about the weather. It's very sunny today.
# Assistant: Sounds great! 🌞 A bright, sunny day is always a good excuse to talk about the weather. Do you happen to know your current location or the city you’re in? That way I can give you a more tailored update—whether it’s the typical high and low temps, humidity, or what the forecast looks like for the next few days. If you prefer, I can keep it more general and chat about sunny weather in general: why it feels so uplifting, how it affects plants, or even fun sunny‑day activities. Let me know what you’re in the mood for!
#
# ### CURRENT REQUEST
# I'm planning to go for a walk later.
# ---
#
# Agent > Sounds like a great idea! A sunny walk is one of the easiest ways to get a little fresh‑air boost. Here are a few quick pointers to help you make the most of it:
#
# | What you might need | Why it helps | Quick check |
# |---------------------|--------------|-------------|
# | **Comfortable shoes** | Protects feet and keeps you steady on any surface. | Are your shoes already broken in? |
# | **Light, breathable layers** | Keeps you cool while still protecting against sun or wind. | Do you have a jacket you can pull on if the temperature dips? |
# | **Sunscreen** | Even on a mild day the UV can still add up. | Have you applied SPF 30+ today? |
# | **Hydration** | Keeps you from overheating. | A reusable water bottle? |
# | **Map/route idea** | Helps you stay on track and find interesting stops. | Do you prefer a park, a trail, or a city walk? |
#
# If you’re up for a little extra planning, I can pull up a local weather forecast or suggest a scenic route based on your city—just let me know where you’re heading. Or if you just want a quick chat about what makes a sunny walk so enjoyable, I’m happy to dive into that too! 🌞🚶‍♀️🚶‍♂️
# (LLM Generation Time: 0.6512 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > I need to log into my account, can you remind me of my ID?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.3955 seconds
# Estimated Prompt Tokens: 535
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Retrieved Long-Term Memories:
# ### Relevant Information Retrieved from Memory:
# AI responded: Got it! I've stored your User ID as **AX-7890**. If you need anything else, just let me know!
# ---
# User said: Please remember my User ID is AX-7890.
#
# ### Recent Conversation (Working Memory):
# User: Let's chat about the weather. It's very sunny today.
# Assistant: Sounds great! 🌞 A bright, sunny day is always a good excuse to talk about the weather. Do you happen to know your current location or the city you’re in? That way I can give you a more tailored update—whether it’s the typical high and low temps, humidity, or what the forecast looks like for the next few days. If you prefer, I can keep it more general and chat about sunny weather in general: why it feels so uplifting, how it affects plants, or even fun sunny‑day activities. Let me know what you’re in the mood for!
# User: I'm planning to go for a walk later.
# Assistant: Sounds like a great idea! A sunny walk is one of the easiest ways to get a little fresh‑air boost. Here are a few quick pointers to help you make the most of it:
#
# | What you might need | Why it helps | Quick check |
# |---------------------|--------------|-------------|
# | **Comfortable shoes** | Protects feet and keeps you steady on any surface. | Are your shoes already broken in? |
# | **Light, breathable layers** | Keeps you cool while still protecting against sun or wind. | Do you have a jacket you can pull on if the temperature dips? |
# | **Sunscreen** | Even on a mild day the UV can still add up. | Have you applied SPF 30+ today? |
# | **Hydration** | Keeps you from overheating. | A reusable water bottle? |
# | **Map/route idea** | Helps you stay on track and find interesting stops. | Do you prefer a park, a trail, or a city walk? |
#
# If you’re up for a little extra planning, I can pull up a local weather forecast or suggest a scenic route based on your city—just let me know where you’re heading. Or if you just want a quick chat about what makes a sunny walk so enjoyable, I’m happy to dive into that too! 🌞🚶‍♀️🚶‍♂️
#
# ### CURRENT REQUEST
# I need to log into my account, can you remind me of my ID?
# ---
#
# Agent > Your User ID is **AX-7890**. If you need help logging in or have any other questions, just let me know!
# (LLM Generation Time: 0.2921 seconds)
# ======================================================================
# Sliding window memory cleared.
# Retrieval memory (documents and FAISS index) cleared.
# Hierarchical memory cleared.

# %% [markdown]
# ### Strategy 7: Graph-Based Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Systems where relationships between facts matter     | Best for structured knowledge, more effort to maintain |
#
# **Theory:** This strategy moves beyond storing unstructured text. It represents information as a **knowledge graph**, consisting of nodes (entities) and edges (relationships). For example, `(Sam) -[WorksFor]-> (Innovatech) -[FocusesOn]-> (Energy)`.
#
# This is incredibly powerful for answering complex queries that require reasoning about connections. The main challenge is populating the graph. We will use a powerful technique: **using the LLM as a tool** to extract structured `(subject, relation, object)` triples from the unstructured conversation text.

# %%
# Import necessary libraries for graph data structures and regular expressions.
import networkx as nx
import re

# --- Strategy 7: Graph-Based Memory ---
# This strategy represents information as a structured knowledge graph, consisting
# of nodes (entities like 'Sam', 'Innovatech') and edges (relationships like
# 'works_for', 'focuses_on'). It uses the LLM itself to extract these structured
# triples (Subject, Relation, Object) from unstructured conversation text.
class GraphMemory(BaseMemoryStrategy):
    def __init__(self):
        """Initializes the memory with an empty NetworkX directed graph."""
        # A DiGraph is suitable for representing directed relationships (e.g., Sam -> works_for -> Innovatech).
        self.graph = nx.DiGraph()

    def _extract_triples(self, text: str) -> list[tuple[str, str, str]]:
        """
        Uses the LLM to extract knowledge triples (Subject, Relation, Object) from a given text.
        This is a form of "LLM as a Tool" where the model's language understanding is
        used to create structured data.
        """
        print("--- [Graph Memory: Attempting to extract triples from text.] ---")
        # Construct a detailed prompt that instructs the LLM on its role and the desired output format.
        # Providing a clear example is crucial for getting reliable, structured output.
        extraction_prompt = (
            f"You are a knowledge extraction engine. Your task is to extract Subject-Relation-Object triples from the given text. "
            f"Format your output strictly as a list of Python tuples. For example: [('Sam', 'works_for', 'Innovatech'), ('Innovatech', 'focuses_on', 'Energy')]. "
            f"If no triples are found, return an empty list [].\n\n"
            f"Text to analyze:\n\"""{text}\""""
        )
        
        # Call the LLM with the specialized prompt.
        response_text = generate_text(extraction_prompt,text)
        
        # Safely parse the string representation of a list of tuples from the LLM's response.
        try:
            # Using regular expressions is a much safer alternative to `eval()`, as it avoids
            # executing arbitrary code that might be maliciously or accidentally included in the LLM's output.
            # This regex looks for patterns matching ('item1', 'item2', 'item3').
            found_triples = re.findall(r"\(['\"](.*?)['\"],\s*['\"](.*?)['\"],\s*['\"](.*?)['\"]\)", response_text)
            print(f"--- [Graph Memory: Response Text{response_text}] ---")
            print(f"--- [Graph Memory: Extracted triples: {found_triples}] ---")
            return found_triples
        except Exception as e:
            # If parsing fails, log the error and return an empty list to prevent crashes.
            print(f"Could not parse triples from LLM response: {e}")
            return []

    def add_message(self, user_input: str, ai_response: str):
        """Extracts triples from the latest conversation turn and adds them to the knowledge graph."""
        # Combine the user and AI messages to provide full context for extraction.
        full_text = f"User: {user_input}\nAI: {ai_response}"
        # Call the helper method to get structured triples.
        triples = self._extract_triples(full_text)
        # Iterate over the extracted triples.
        for subject, relation, obj in triples:
            # Add an edge to the graph. `add_edge` automatically creates the nodes
            # (subject, obj) if they don't already exist. The relation is stored as an edge attribute.
            # .strip() removes any leading/trailing whitespace for cleaner data.
            self.graph.add_edge(subject.strip(), obj.strip(), relation=relation.strip())

    def get_context(self, query: str) -> str:
        """
        Retrieves context by finding entities from the query in the graph and
        returning all their known relationships.
        """
        # If the graph is empty, there's no context to provide.
        if not self.graph.nodes:
            return "The knowledge graph is empty."
        else:
            print(f"--- [Graph Memory: Current Graph Nodes: {self.graph.nodes}] ---")
            print(f"--- [Graph Memory: Current Graph Edges: {self.graph.edges(data=True)}] ---")
        
        # This is a simple entity linking method: it capitalizes words in the query and checks
        # if they exist as nodes in the graph. A more advanced system would use Natural
        # Language Processing (NLP) to identify named entities more accurately.
        query_entities = [word.capitalize() for word in query.replace('?','').split() if word.capitalize() in self.graph.nodes]
        
        # If no entities from the query are found in our graph, we can't provide specific context.
        if not query_entities:
            print(f"--- [Graph Memory: Query '{query}' yielded no matching entities.] ---")
            return "No relevant entities from your query were found in the knowledge graph."
        
        context_parts = []
        # Use set() to process each unique entity only once.
        for entity in set(query_entities):
            # Find all outgoing edges (e.g., Sam -> works_for -> X)
            for u, v, data in self.graph.out_edges(entity, data=True):
                context_parts.append(f"{u} --[{data['relation']}]--> {v}")
            # Find all incoming edges (e.g., X -> is_located_in -> New York)
            for u, v, data in self.graph.in_edges(entity, data=True):
                context_parts.append(f"{u} --[{data['relation']}]--> {v}")
        
        # Combine the retrieved facts into a single context string, removing duplicates and sorting for consistency.
        return "### Facts Retrieved from Knowledge Graph:\n" + "\n".join(sorted(list(set(context_parts))))

    def clear(self):
        """Resets the memory by clearing all nodes and edges from the graph."""
        self.graph.clear()
        print("Graph memory cleared.")

# %% [markdown]
# #### Demonstration of Graph-Based Memory
#
# **What to watch for:** As we chat, the agent will call the LLM to extract triples and build its knowledge graph. You will see the `[Extracted triples]` debug message. When we finally ask a question, the agent will provide context by showing the structured relationships it has learned, allowing it to answer questions about how different entities are connected.

# %%
# Initialize the GraphMemory strategy.
graph_memory = GraphMemory()
# Create an AIAgent and inject the graph memory strategy.
agent = AIAgent(memory_strategy=graph_memory)

# --- Start the conversation ---
# First turn: The agent will attempt to extract the triple ('Clara', 'works_for', 'FutureScape').
agent.chat("A person named Clara works for a company called 'FutureScape'.")
# Second turn: The agent will attempt to extract the triple ('FutureScape', 'is_based_in', 'Berlin').
agent.chat("FutureScape is based in Berlin.")
# Third turn: The agent will attempt to extract the triple ('Clara', 'main_project_is', 'Odyssey').
agent.chat("Clara's main project is named 'Odyssey'.")

# --- Test the graph reasoning ---
# Now, ask a question that requires connecting the dots.
# The agent will identify 'Clara' as an entity in the query. It will then search the graph
# for all relationships connected to the 'Clara' node and use this structured information
# as context for the LLM.
agent.chat("Tell me about Clara project.")
# The agent should be able to use the extracted facts to infer the connection between Clara and her project.

# Clean up the memory for the next demonstration.
graph_memory.clear()
# Out:
# Agent initialized with GraphMemory.
#
# ========================= NEW INTERACTION =========================
# User > A person named Clara works for a company called 'FutureScape'.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 35
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# The knowledge graph is empty.
#
# ### CURRENT REQUEST
# A person named Clara works for a company called 'FutureScape'.
# ---
# --- [Graph Memory: Attempting to extract triples from text.] ---
# --- [Graph Memory: Response Text[('Clara', 'works_for', 'FutureScape')]] ---
# --- [Graph Memory: Extracted triples: [('Clara', 'works_for', 'FutureScape')]] ---
#
# Agent > Got it—Clara is an employee of FutureScape. Let me know if you need anything else!
# (LLM Generation Time: 0.5516 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > FutureScape is based in Berlin.
# --- [Graph Memory: Current Graph Nodes: ['Clara', 'FutureScape']] ---
# --- [Graph Memory: Current Graph Edges: [('Clara', 'FutureScape', {'relation': 'works_for'})]] ---
# --- [Graph Memory: Query 'FutureScape is based in Berlin.' yielded no matching entities.] ---
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0001 seconds
# Estimated Prompt Tokens: 36
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# No relevant entities from your query were found in the knowledge graph.
#
# ### CURRENT REQUEST
# FutureScape is based in Berlin.
# ---
# --- [Graph Memory: Attempting to extract triples from text.] ---
# --- [Graph Memory: Response Text[('FutureScape', 'based_in', 'Berlin')]] ---
# --- [Graph Memory: Extracted triples: [('FutureScape', 'based_in', 'Berlin')]] ---
#
# Agent > Got it! FutureScape is based in Berlin. How can I help you with this information?
# (LLM Generation Time: 0.3086 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Clara's main project is named 'Odyssey'.
# --- [Graph Memory: Current Graph Nodes: ['Clara', 'FutureScape', 'Berlin']] ---
# --- [Graph Memory: Current Graph Edges: [('Clara', 'FutureScape', {'relation': 'works_for'}), ('FutureScape', 'Berlin', {'relation': 'based_in'})]] ---
# --- [Graph Memory: Query 'Clara's main project is named 'Odyssey'.' yielded no matching entities.] ---
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0001 seconds
# Estimated Prompt Tokens: 39
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# No relevant entities from your query were found in the knowledge graph.
#
# ### CURRENT REQUEST
# Clara's main project is named 'Odyssey'.
# ---
# --- [Graph Memory: Attempting to extract triples from text.] ---
# --- [Graph Memory: Response Text[('Clara', 'has_main_project', 'Odyssey')]] ---
# --- [Graph Memory: Extracted triples: [('Clara', 'has_main_project', 'Odyssey')]] ---
#
# Agent > Got it—Clara’s main project is called **Odyssey**. How can I help you with it today? Whether you’re looking for project planning tips, resource ideas, or just want to share more details, I’m here for it.
# (LLM Generation Time: 0.4306 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Tell me about Clara project.
# --- [Graph Memory: Current Graph Nodes: ['Clara', 'FutureScape', 'Berlin', 'Odyssey']] ---
# --- [Graph Memory: Current Graph Edges: [('Clara', 'FutureScape', {'relation': 'works_for'}), ('Clara', 'Odyssey', {'relation': 'has_main_project'}), ('FutureScape', 'Berlin', {'relation': 'based_in'})]] ---
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0001 seconds
# Estimated Prompt Tokens: 51
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Facts Retrieved from Knowledge Graph:
# Clara --[has_main_project]--> Odyssey
# Clara --[works_for]--> FutureScape
#
# ### CURRENT REQUEST
# Tell me about Clara project.
# ---
# --- [Graph Memory: Attempting to extract triples from text.] ---
# --- [Graph Memory: Response Text[('Clara', 'main_project', 'Odyssey'), ('Odyssey', 'owner', 'Clara'), ('Odyssey', 'organization', 'FutureScape'), ('Clara', 'driving_force_of', 'Odyssey'), ('Clara', 'focuses_on', 'Odyssey')]] ---
# --- [Graph Memory: Extracted triples: [('Clara', 'main_project', 'Odyssey'), ('Odyssey', 'owner', 'Clara'), ('Odyssey', 'organization', 'FutureScape'), ('Clara', 'driving_force_of', 'Odyssey'), ('Clara', 'focuses_on', 'Odyssey')]] ---
#
# Agent > **Clara’s main project – Odyssey**
#
# - **Project name:** *Odyssey*
# - **Owner:** Clara
# - **Organization:** FutureScape
#
# The available knowledge indicates that Clara is the principal driving force behind the Odyssey initiative at FutureScape. While the facts don’t provide further technical or functional details about Odyssey itself, we know that it’s the central focus of Clara’s current work. If you’d like more specific information (such as objectives, scope, or technology stack), let me know and I can look for additional details!
# (LLM Generation Time: 0.6327 seconds)
# ======================================================================
# Graph memory cleared.

# %% [markdown]
# ### Strategy 8: Compression & Consolidation Memory
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Scalable memory at lower cost                        | Risk of lossy or overly abstract recall                |
#
# **Theory:** This is a more explicit and aggressive form of summarization. Instead of creating a narrative summary, the goal is to compress each piece of information into its most dense, factual representation. Think of it like converting a verbose paragraph into a few bullet points.
#
# Our implementation will take each conversational turn and use the LLM to re-write it as a concise, compressed fact. The memory is simply a list of these compressed facts. This can save a significant number of tokens compared to storing the full text, but the risk of losing nuance is even higher than with standard summarization.

# %%
class CompressionMemory(BaseMemoryStrategy):
    def __init__(self):
        self.compressed_facts = []

    def add_message(self, user_input: str, ai_response: str):
        """Uses the LLM to compress the turn into a dense fact."""
        text_to_compress = f"User: {user_input}\nAI: {ai_response}"
        
        compression_prompt = (
            f"You are a data compression engine. Your task is to distill the following text into its most essential, factual statement. "
            f"Be as concise as possible, removing all conversational fluff. For example, 'User asked about my name and I, the AI, responded that my name is an AI assistant' should become 'User asked for AI's name.'\n\n"
            f"Text to compress:\n\"""{text_to_compress}\""""
        )
        
        compressed_fact = generate_text( compression_prompt,text_to_compress)
        print(f"--- [Compression Memory: New fact stored: '{compressed_fact}'] ---")
        self.compressed_facts.append(compressed_fact)

    def get_context(self, query: str) -> str:
        """Returns the list of all compressed facts."""
        if not self.compressed_facts:
            return "No compressed facts in memory."
        
        return "### Compressed Factual Memory:\n- " + "\n- ".join(self.compressed_facts)

    def clear(self):
        self.compressed_facts = []
        print("Compression memory cleared.")

# %% [markdown]
# #### Demonstration of Compression Memory
#
# **What to watch for:** After each turn, a `[Compression Memory: New fact stored]` message will appear, showing the highly condensed version of the interaction. The final context sent to the LLM will be a bulleted list of these terse facts, which is much more token-efficient than the original conversation.

# %%
compression_memory = CompressionMemory()
agent = AIAgent(memory_strategy=compression_memory)

agent.chat("Okay, I've decided on the venue for the conference. It's going to be the 'Metropolitan Convention Center'.")
agent.chat("The date is confirmed for October 26th, 2025.")
agent.chat("Could you please summarize the key details for the conference plan?")

compression_memory.clear()
# Out:
# Agent initialized with CompressionMemory.
#
# ========================= NEW INTERACTION =========================
# User > Okay, I've decided on the venue for the conference. It's going to be the 'Metropolitan Convention Center'.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 45
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# No compressed facts in memory.
#
# ### CURRENT REQUEST
# Okay, I've decided on the venue for the conference. It's going to be the 'Metropolitan Convention Center'.
# ---
# --- [Compression Memory: New fact stored: 'User chose the Metropolitan Convention Center as the venue.'] ---
#
# Agent > Great choice! The Metropolitan Convention Center is known for its modern amenities and central location. How can I help you next—perhaps with room layout, catering options, or attendee logistics? Feel free to share any details or questions you have!
# (LLM Generation Time: 0.5960 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > The date is confirmed for October 26th, 2025.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 47
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Compressed Factual Memory:
# - User chose the Metropolitan Convention Center as the venue.
#
# ### CURRENT REQUEST
# The date is confirmed for October 26th, 2025.
# ---
# --- [Compression Memory: New fact stored: 'Event scheduled for October 26, 2025 at Metropolitan Convention Center. Tasks: confirm attendance, outline agenda, define AV needs, finalize catering, prepare signage, arrange transportation, set registration, book vendors, develop contingency plans.'] ---
#
# Agent > Great news!
# 📅 **Event Date:** October 26, 2025
# 📍 **Venue:** Metropolitan Convention Center
#
# The venue and date are locked in, so we can start putting the rest of the event details together. Here’s a quick checklist of next steps to keep the planning on track:
#
# | Item | What’s next? |
# |------|--------------|
# | **Attendance** | Confirm the expected headcount and any special accommodation needs. |
# | **Agenda** | Outline the program flow (keynotes, breaks, networking, etc.). |
# | **AV & Tech** | Determine audio/visual requirements and any on‑site tech support. |
# | **Catering** | Decide on meal style, dietary restrictions, and beverage service. |
# | **Signage & Branding** | Prepare on‑site branding elements and directional signage. |
# | **Transportation & Parking** | Arrange shuttles or parking info for attendees. |
# | **Registration** | Set up online registration or ticketing platform if needed. |
# | **Vendor Coordination** | Book any external vendors (photographer, DJ, etc.). |
# | **Contingency Plans** | Prepare backup plans for weather or tech hiccups. |
#
# Let me know which areas you’d like to tackle first or if you have any special requests (e.g., a specific room layout, accessibility requirements, or a themed décor). I’m happy to dive into any of these details and help you keep everything moving smoothly!
# (LLM Generation Time: 0.6187 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > Could you please summarize the key details for the conference plan?
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 94
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Compressed Factual Memory:
# - User chose the Metropolitan Convention Center as the venue.
# - Event scheduled for October 26, 2025 at Metropolitan Convention Center. Tasks: confirm attendance, outline agenda, define AV needs, finalize catering, prepare signage, arrange transportation, set registration, book vendors, develop contingency plans.
#
# ### CURRENT REQUEST
# Could you please summarize the key details for the conference plan?
# ---
# --- [Compression Memory: New fact stored: 'Conference on Oct 26, 2025 at Metropolitan Convention Center: finalize attendance, agenda, AV, catering, signage, transportation, registration, vendor contracts, and contingency plans.'] ---
#
# Agent > **Conference Overview – October 26, 2025**
#
# | Item | Detail |
# |------|--------|
# | **Venue** | Metropolitan Convention Center |
# | **Date** | October 26, 2025 |
# | **Main Objectives** | • Confirm attendance numbers<br>• Finalize agenda<br>• Define AV requirements<br>• Secure catering options<br>• Prepare signage and branding<br>• Arrange transportation & parking<br>• Set up registration & ticketing<br>• Book all vendors (catering, AV, décor, security, etc.)<br>• Develop and document contingency plans (weather, technical failures, health/safety) |
#
# **Key Action Items (to be completed)**
#
# 1. **Attendance** – Send out RSVP reminders; lock in final headcount.
# 2. **Agenda** – Draft session schedule, speaker slots, and breaks; circulate for approvals.
# 3. **AV** – List required equipment (projectors, microphones, live‑streaming gear), test in-room connectivity, and book any external tech support.
# 4. **Catering** – Select menu (breakfast, lunch, snacks, beverages), confirm dietary accommodations, and finalize contracts.
# 5. **Signage** – Design directional and informational signs; coordinate with venue’s graphics team.
# 6. **Transportation** – Book shuttles or parking arrangements for attendees; provide itineraries.
# 7. **Registration** – Set up online registration portal, print badges, and plan check‑in process.
# 8. **Vendors** – Confirm contracts with catering, AV, décor, security, and other suppliers.
# 9. **Contingency Plans** – Outline backup venues, emergency protocols, and backup equipment lists.
#
# These points cover the core pillars needed to move the conference from planning to execution. Once each task is verified, you’ll have a ready‑to‑go plan for the event on October 26th.
# (LLM Generation Time: 0.6385 seconds)
# ======================================================================
# Compression memory cleared.

# %% [markdown]
# ### Strategy 9: OS-Like Memory Management (Conceptual Simulation)
#
# | **Best For**                  | **Tradeoff**                                           |
# | ----------------------------- | ------------------------------------------------------ |
# | Large-scale systems with dynamic memory requirements | Conceptually powerful, architecturally complex         |
#
# **Theory:** This advanced concept borrows from how a computer's Operating System manages memory. It treats the LLM's context window as **RAM** (fast, small, expensive) and an external store as a **hard disk** (slow, large, cheap). Information is moved between them.
# - **Paging Out:** When RAM (the active context) is full, a policy (like Least Recently Used - LRU) moves the oldest information to the hard disk (a passive store).
# - **Paging In (Page Fault):** When a query needs information that isn't in RAM, a "page fault" occurs. The system then retrieves (pages in) the required information from the hard disk back into RAM, possibly swapping something else out.
#
# **Our Simulation:** We'll create an `active_memory` (list) and a `passive_memory` (dict for fast lookups). When `active_memory` is full, we'll move the LRU item to `passive_memory`. Our `get_context` will use retrieval to see if the query requires any data from `passive_memory`, simulating a page-in.

# %%
class OSMemory(BaseMemoryStrategy):
    def __init__(self, ram_size: int = 2):
        self.ram_size = ram_size # Max number of turns in active memory (RAM)
        self.active_memory = deque() # Our 'RAM'
        self.passive_memory = {} # Our 'Hard Disk', a key-value store
        self.turn_count = 0

    def add_message(self, user_input: str, ai_response: str):
        """Adds a turn to active memory, paging out to passive if RAM is full."""
        turn_id = self.turn_count
        turn_data = f"User: {user_input}\nAI: {ai_response}"
        
        if len(self.active_memory) >= self.ram_size:
            # Page out the least recently used (oldest) item from RAM
            lru_turn_id, lru_turn_data = self.active_memory.popleft()
            self.passive_memory[lru_turn_id] = lru_turn_data
            print(f"--- [OS Memory: Paging out Turn {lru_turn_id} to passive storage.] ---")
        
        # Add the new turn to active memory (RAM)
        self.active_memory.append((turn_id, turn_data))
        self.turn_count += 1

    def get_context(self, query: str) -> str:
        """Provides RAM context and simulates a 'page fault' to pull from passive memory."""
        active_context = "\n".join([data for _, data in self.active_memory])
        
        # Simulate a page fault: check if the query is more similar to something in passive memory
        # In a real system, this would use embeddings for similarity search.
        # For this demo, we'll do a simple keyword search.
        paged_in_context = ""
        for turn_id, data in self.passive_memory.items():
            if any(word in data.lower() for word in query.lower().split() if len(word) > 3):
                paged_in_context += f"\n(Paged in from Turn {turn_id}): {data}"
                print(f"--- [OS Memory: Page fault! Paging in Turn {turn_id} from passive storage.] ---")
        
        return f"### Active Memory (RAM):\n{active_context}\n\n### Paged-In from Passive Memory (Disk):\n{paged_in_context}"

    def clear(self):
        self.active_memory.clear()
        self.passive_memory = {}
        self.turn_count = 0
        print("OS-like memory cleared.")

# %% [markdown]
# #### Demonstration of OS-Like Memory
#
# **What to watch for:** We will have a conversation where the first turn contains a secret code. As we continue, you'll see a `[Paging out]` message as this turn is moved from "RAM" to "Disk". When we finally ask about the secret code, a `[Page fault!]` will be triggered, and the agent will "page in" that specific memory to answer the question.

# %%
os_memory = OSMemory(ram_size=2)
agent = AIAgent(memory_strategy=os_memory)

agent.chat("The secret launch code is 'Orion-Delta-7'.")
agent.chat("The weather for the launch looks clear.")
agent.chat("The launch window opens at 0400 Zulu.") # This will page out the secret code turn

# Now, ask about the paged-out information
agent.chat("I need to confirm the launch code.")

os_memory.clear()
# Out:
# Agent initialized with OSMemory.
#
# ========================= NEW INTERACTION =========================
# User > The secret launch code is 'Orion-Delta-7'.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 46
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Active Memory (RAM):
#
#
# ### Paged-In from Passive Memory (Disk):
#
#
# ### CURRENT REQUEST
# The secret launch code is 'Orion-Delta-7'.
# ---
#
# Agent > Got it—'Orion‑Delta‑7' is the secret launch code. Let me know how else I can assist!
# (LLM Generation Time: 0.7139 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > The weather for the launch looks clear.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 83
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Active Memory (RAM):
# User: The secret launch code is 'Orion-Delta-7'.
# AI: Got it—'Orion‑Delta‑7' is the secret launch code. Let me know how else I can assist!
#
# ### Paged-In from Passive Memory (Disk):
#
#
# ### CURRENT REQUEST
# The weather for the launch looks clear.
# ---
#
# Agent > Sounds like the launch window is looking good. I’ll keep an eye on any changes and let you know if anything comes up. Anything else you’d like to check or prepare before go‑live?
# (LLM Generation Time: 0.4319 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > The launch window opens at 0400 Zulu.
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 138
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Active Memory (RAM):
# User: The secret launch code is 'Orion-Delta-7'.
# AI: Got it—'Orion‑Delta‑7' is the secret launch code. Let me know how else I can assist!
# User: The weather for the launch looks clear.
# AI: Sounds like the launch window is looking good. I’ll keep an eye on any changes and let you know if anything comes up. Anything else you’d like to check or prepare before go‑live?
#
# ### Paged-In from Passive Memory (Disk):
#
#
# ### CURRENT REQUEST
# The launch window opens at 0400 Zulu.
# ---
# --- [OS Memory: Paging out Turn 0 to passive storage.] ---
#
# Agent > Got it—launch window opens at 0400 Z. Everything else is set (code “Orion‑Delta‑7”, weather clear). I’ll keep an eye on any last‑minute changes and will ping the team when the window opens. Let me know if you need anything else before go‑live.
# (LLM Generation Time: 0.4395 seconds)
# ======================================================================
#
# ========================= NEW INTERACTION =========================
# User > I need to confirm the launch code.
# --- [OS Memory: Page fault! Paging in Turn 0 from passive storage.] ---
#
# --- Agent Debug Info ---
# Memory Retrieval Time: 0.0000 seconds
# Estimated Prompt Tokens: 222
#
# [Full Prompt Sent to LLM]:
# ---
# SYSTEM: You are a helpful AI assistant.
# USER: ### MEMORY CONTEXT
# ### Active Memory (RAM):
# User: The weather for the launch looks clear.
# AI: Sounds like the launch window is looking good. I’ll keep an eye on any changes and let you know if anything comes up. Anything else you’d like to check or prepare before go‑live?
# User: The launch window opens at 0400 Zulu.
# AI: Got it—launch window opens at 0400 Z. Everything else is set (code “Orion‑Delta‑7”, weather clear). I’ll keep an eye on any last‑minute changes and will ping the team when the window opens. Let me know if you need anything else before go‑live.
#
# ### Paged-In from Passive Memory (Disk):
#
# (Paged in from Turn 0): User: The secret launch code is 'Orion-Delta-7'.
# AI: Got it—'Orion‑Delta‑7' is the secret launch code. Let me know how else I can assist!
#
# ### CURRENT REQUEST
# I need to confirm the launch code.
# ---
# --- [OS Memory: Paging out Turn 1 to passive storage.] ---
#
# Agent > ✅ **Launch code confirmed**: **“Orion‑Delta‑7”**. Let me know if you need anything else!
# (LLM Generation Time: 0.2976 seconds)
# ======================================================================
# OS-like memory cleared.

# %% [markdown]
# ## Lab Conclusion and Final Thoughts
#
# Congratulations on completing this deep dive into AI agent memory! We have successfully implemented and tested nine distinct strategies, observing firsthand how each one impacts an agent's performance, cost, and capabilities.
#
# **Key Takeaways from this Lab:**
#
# 1.  **There is No Silver Bullet:** The choice of memory is fundamentally a design decision based on your agent's purpose. A simple Q&A bot might only need a `SlidingWindow`, while a long-term personal assistant would thrive on a `Hierarchical` or `Retrieval` system.
#
# 2.  **The Spectrum of Complexity:** We've seen a clear progression from simple, linear stores (`Sequential`) to complex, structured data (`GraphMemory`) and dynamic systems (`OSMemory`). Increasing complexity offers more power but requires more sophisticated engineering.
#
# 3.  **LLMs as Tools:** Several advanced strategies (`Summarization`, `GraphMemory`, `MemoryAugmented`) don't just use the LLM for chat; they use it as an intelligent tool for processing, structuring, and compressing memory itself. This is a powerful paradigm in modern agent design.
#
# 4.  **Hybrid Systems are the Future:** The most robust production agents often use hybrid approaches. Our `HierarchicalMemory` is a prime example, combining the speed of a sliding window with the precision of retrieval. You can mix and match these strategies to create a custom memory architecture tailored to your exact needs.
#
# ### Next Steps
#
# This notebook is a starting point. You can continue to explore by:
# - **Tuning Parameters:** Adjust `window_size`, `k` for retrieval, and summarization thresholds to see how they affect performance.
# - **Implementing More Advanced Logic:** Improve the promotion logic in `HierarchicalMemory` or the page-fault detection in `OSMemory` using embeddings.
# - **Creating New Hybrids:** Combine `GraphMemory` with `RetrievalMemory` to search both structured and unstructured data simultaneously.
#
# Thank you for joining this lab. Happy building!
